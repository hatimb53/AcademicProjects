# %%
import numpy as np
import pickle

# %%
def load():
    with open("../../datasets/mnist.pkl",'rb') as f:
        mnist = pickle.load(f)
    return mnist["training_images"], mnist["training_labels"], mnist["test_images"], mnist["test_labels"]

(xtrain,ytrain,xtest,ytest)=load()
print(xtrain.shape,ytrain.shape)

# %%
class CNN:
    def __init__(self,alpha):
        self.hidden={}
        self.weights={}
        self.bias={}
        self.stride={}
        self.padding={}
        self.window={}
        self.count=0
        self.layers=[]
        self.layers_shape={}
        self.grad={}
        self.alpha=alpha
        

        
               
    def fit(self,x,y,epoch=1,batch_size=100):
        
        step=(int)(x.shape[0]/batch_size)
    
        for j in range(epoch):
            data_size=batch_size
            for i in range(step):
               
                
                batchx=x[(i)*batch_size:(i+1)*batch_size]
               
                batchy=y[(i)*batch_size:(i+1)*batch_size]
               
                yp=np.argmax(self.predict(batchx,batchy),axis=1)
                self.backpropagate(batchy)

                ya=np.argmax(batchy,axis=1)
                accuracy=(np.where(yp==ya)[0].shape[0]/yp.shape[0])
                
                #print("epoch=",j," step=",i," shape=",batchy.shape)
                
                print("epoch=",j," step=",i," accuracy=",accuracy)
                
                
          
            if(x.shape[0]%batch_size>0):
                batchx=x[step*batch_size:]
                batchy=y[step*batch_size:]
                
                yp=np.argmax(self.predict(batchx,batchy),axis=1)
                self.backpropagate(batchy) 

                ya=np.argmax(batchy,axis=1)
                accuracy=(np.where(yp==ya)[0].shape[0]/yp.shape[0])
                
                #print("epoch=",j," step=",i," shape=",batchy.shape)
                
                print("epoch=",j," step=",i," accuracy=",accuracy)
                
                
                  
        
        
    def predict(self,x,y):
        
        for i in range(len(self.layers)):
           
            if "input" in self.layers[i]:
                self.hidden[self.layers[i]]=x
            if "conv2d" in self.layers[i]:
                self.cnn_2d(i,False)
            elif "maxpool2d" in self.layers[i]:
                self.max_pool_2d(i,False)
            elif "avgpool2d" in self.layers[i]:
                self.avg_pool_2d(i,False)
            elif "dense" in self.layers[i]:
                self.dense_layer(i,False)
            elif "flatten" in self.layers[i]:
                self.flatten_layer(i,False)
            elif "relu" in self.layers[i]:
                self.relu_layer(i,False)
            elif "sigmoid" in self.layers[i]:
                self.sigmoid_layer(i,False)
            elif "softmax" in self.layers[i]:
                self.softmax_layer(i,False)
            elif "crossentropy" in self.layers[i]:
                self.cross_entropy_loss(i,False,y)  
            
            #print(self.layers[i],self.hidden[self.layers[i]])
      
        return self.hidden[self.layers[len(self.layers)-2]]
        
        
    
    def backpropagate(self,y):
            
       
        for i in range(len(self.layers)-1,0,-1):
          
           
            if "conv2d" in self.layers[i]:
                self.cnn_2d(i,True)
            elif "maxpool2d" in self.layers[i]:
                self.max_pool_2d(i,True)
            elif "avgpool2d" in self.layers[i]:
                self.avg_pool_2d(i,True)
            elif "dense" in self.layers[i]:
                self.dense_layer(i,True)
            elif "flatten" in self.layers[i]:
                self.flatten_layer(i,True)
            elif "relu" in self.layers[i]:
                self.relu_layer(i,True)
            elif "sigmoid" in self.layers[i]:
                self.sigmoid_layer(i,True)
            elif "softmax" in self.layers[i]:
                self.softmax_layer(i,True)
            elif "crossentropy" in self.layers[i]:
                self.cross_entropy_loss(i,True,y)

                
    #operations            
      
    def im2_col(self,x,window,stride):
        
        n1=(int)((x.shape[1]-window[0])/stride[0])+1
        n2=(int)((x.shape[2]-window[1])/stride[1])+1
       
        k1=window[0]
        k2=window[1]
        k3=window[2]
        
        (i)=np.fromfunction(lambda i:(i),(n1*n2*k1*k2*k3,),dtype=(int))


        tmp1=((i/(n2*k1*k2*k3)).astype(int))*stride[0]
        tmp2=((i%(n2*k1*k2*k3))/(k1*k2*k3)).astype(int)*stride[1]

        p=(i%(k1*k2*k3)/(k2*k3)).astype(int)

        p=p+tmp1
        q=tmp2+((i%(k2*k3))/k3).astype(int)

        r=i%k3
        
        x=x[:,p,q,r].reshape(x.shape[0],n1*n2,k1,k2,k3)
        return x
    
    
    
    def col2_img(self,grad,window,stride,shape):
        
        x=np.zeros(shape)
        
        n1=(int)((x.shape[1]-window[0])/stride[0])+1
        n2=(int)((x.shape[2]-window[1])/stride[1])+1
      
        k1=window[0]
        k2=window[1]
        k3=window[2]
        
        (i)=np.fromfunction(lambda i:(i),(n1*n2*k1*k2*k3,),dtype=(int))


        tmp1=((i/(n2*k1*k2*k3)).astype(int))*stride[0]
        tmp2=((i%(n2*k1*k2*k3))/(k1*k2*k3)).astype(int)*stride[1]

        p=(i%(k1*k2*k3)/(k2*k3)).astype(int)

        p=p+tmp1
        q=tmp2+((i%(k2*k3))/k3).astype(int)

        r=i%k3
        
        
       
        x=x.reshape(shape[0],shape[1]*shape[2]*shape[3])
        ind=(p+q*shape[1]+r*shape[2]*shape[3])

        
        for i in range(x.shape[0]):
            np.add.at(x[i],ind,grad[i])
            
        return x.reshape(shape[0],shape[1],shape[2],shape[3])
        

        
    def cnn_2d(self,layer,grad):
       
        
        x=self.hidden[self.layers[layer-1]]
      
        if(self.padding[self.layers[layer]]=='same'):
            padx=x.shape[1]*(self.stride[self.layers[layer]][0]-1)+self.weights[self.layers[layer]].shape[0]-self.stride[self.layers[layer]][0]
            pady=x.shape[2]*(self.stride[self.layers[layer]][1]-1)+self.weights[self.layers[layer]].shape[1]-self.stride[self.layers[layer]][1]
            
         
            if padx%2==0:
                padx1=padx/2
                padx2=padx/2
            else:
                padx1=(int)(padx/2)
                padx2=(int)(padx/2)+1
                
            if pady%2==0:
                pady1=pady/2
                pady2=pady/2
            else:
                pady1=(int)(pady/2)
                pady2=(int)(pady/2)+1
            
            x=np.pad(x, [(0,0),((int)(padx1), (int)(padx2)), ((int)(pady1), (int)(pady2)),(0,0)], mode='constant', constant_values=0)
            
            
        shapei=x.shape
        
       
        shapex=(int)((x.shape[1]-self.weights[self.layers[layer]].shape[0])/self.stride[self.layers[layer]][0])+1
        shapey=(int)((x.shape[2]-self.weights[self.layers[layer]].shape[1])/self.stride[self.layers[layer]][1])+1
        
        
        
       
        
        n=x.shape[0]
        d=self.weights[self.layers[layer]].shape[3]
        

        x=self.im2_col(x,self.weights[self.layers[layer]].shape,self.stride[self.layers[layer]])
        
        
        if grad==False:
            
            

            x=x.reshape(x.shape[0]*x.shape[1],x.shape[2]*x.shape[3]*x.shape[4])
            w=self.weights[self.layers[layer]].reshape(self.weights[self.layers[layer]].shape[0]*self.weights[self.layers[layer]].shape[1]*self.weights[self.layers[layer]].shape[2],self.weights[self.layers[layer]].shape[3])
            
          
            
            output=np.dot(x,w)+self.bias[self.layers[layer]]


            output=output.reshape(n,shapex,shapey,d)




            self.hidden[self.layers[layer]]=output
          

        else:
            
            w=self.weights[self.layers[layer]]
            shapew=w.shape
            w=w.reshape(w.shape[0]*w.shape[1]*w.shape[2],w.shape[3])
            
            shape=x.shape
            inp=x.reshape(x.shape[0]*x.shape[1],x.shape[2]*x.shape[3]*x.shape[4])
            tmp=self.grad[self.layers[layer+1]]
            grad=tmp.reshape(tmp.shape[0]*tmp.shape[1]*tmp.shape[2],tmp.shape[3])
            
            #print("n=",n)
            #print(grad)
            dw=np.dot(inp.T,grad)/n

            db=grad.sum(axis=0)/n
            
               
            #print("convw=",dw)
            #print("convb=",db)
            
            grad=np.dot(grad,w.T).reshape(shape[0],shape[1]*shape[2]*shape[3]*shape[4])
            

            
            self.weights[self.layers[layer]]-=self.alpha*dw.reshape(shapew[0],shapew[1],shapew[2],shapew[3])
            self.bias[self.layers[layer]]-=self.alpha*db
            
            tmp=self.col2_img(grad,(self.weights[self.layers[layer]].shape[0],self.weights[self.layers[layer]].shape[1],self.weights[self.layers[layer]].shape[2]),self.stride[self.layers[layer]],shapei)
            
            
            
            
            self.grad[self.layers[layer]]=tmp[:,padx1:tmp.shape[1]-padx2,pady1:tmp.shape[2]-pady2,:]
            
            
    def max_pool_2d(self,layer,grad):
        x=self.hidden[self.layers[layer-1]]
 
        shape=x.shape
        shapex=(int)((x.shape[1]-self.window[self.layers[layer]][0])/self.stride[self.layers[layer]][0])+1
        shapey=(int)((x.shape[2]-self.window[self.layers[layer]][1])/self.stride[self.layers[layer]][1])+1

        n=x.shape[0]
        d=x.shape[3]
        x=self.im2_col(x,(self.window[self.layers[layer]][0],self.window[self.layers[layer]][1],d),self.stride[self.layers[layer]])
        
        x=np.transpose(x,(0,1,4,2,3))
        x=x.reshape(x.shape[0],x.shape[1],x.shape[2],x.shape[3]*x.shape[4])
        
        if grad==False:

            output=np.max(x,axis=3)

            output=output.reshape(x.shape[0],shapex,shapey,d)

            self.hidden[self.layers[layer]]=output
      
        
        else:

            n_classes=shape[1]*shape[2]
            
            
            grad=self.grad[self.layers[layer+1]]

            a = np.arange(n_classes)
            b = np.zeros((n_classes, n_classes))
            b[np.arange(n_classes), a] = 1
            
            grad=b[np.argmax(x,axis=3)]*grad.reshape(grad.shape[0],grad.shape[1]*grad.shape[2],grad.shape[3],1)
            
            grad=np.transpose(grad,(0,1,3,2)).reshape(grad.shape[0]*grad.shape[1],grad.shape[2]*grad.shape[3])
            
            
            self.grad[self.layers[layer]]=self.col2_img(grad,(self.window[self.layers[layer]][0],self.window[self.layers[layer]][1],d),self.stride[self.layers[layer]],shape)
            
            
            
            
                        
                        
    def avg_pool_2d(self,layer,grad):
      
        x=self.hidden[self.layers[layer-1]]
        shape=x.shape
        shapex=(int)((x.shape[1]-self.window[self.layers[layer]][0])/self.stride[self.layers[layer]][0])+1
        shapey=(int)((x.shape[2]-self.window[self.layers[layer]][1])/self.stride[self.layers[layer]][1])+1

        n=x.shape[0]
        d=x.shape[3]
        
        x=self.im2_col(x,(self.window[self.layers[layer]][0],self.window[self.layers[layer]][1],d),self.stride[self.layers[layer]])
        
        x=np.transpose(x,(0,1,4,2,3))
        
       
        x=x.reshape(x.shape[0],x.shape[1],x.shape[2],x.shape[3]*x.shape[4])
        
        if grad==False:
            
            output=np.sum(x,axis=3)/(self.window[self.layers[layer]][0]*self.window[self.layers[layer]][1])

            output=output.reshape(x.shape[0],shapex,shapey,d)
            
            self.hidden[self.layers[layer]]=output
           
        
        else:
            #print(x.shape)
            
            tmp=(1/(np.sum(x,axis=3)+0.00001)).reshape(x.shape[0],x.shape[1],x.shape[2],1)
            #print(np.sum(x,axis=3))
            #print("avg2=",tmp)
            grad=self.grad[self.layers[layer+1]]
            
            #print("avg1=",grad)
            tmp2=grad.reshape(grad.shape[0],grad.shape[1]*grad.shape[2],grad.shape[3],1)

            grad=x*tmp*tmp2
                     
            grad=np.transpose(grad,(0,1,3,2)).reshape(grad.shape[0],grad.shape[1]*grad.shape[2]*grad.shape[3])
            
            #print("avg=",grad)
            self.grad[self.layers[layer]]=self.col2_img(grad,(self.window[self.layers[layer]][0],self.window[self.layers[layer]][1],d),self.stride[self.layers[layer]],shape)

        
        
                        
        
    def dense_layer(self,layer,grad):
        if grad==False:
            
            self.hidden[self.layers[layer]]=np.dot(self.hidden[self.layers[layer-1]],self.weights[self.layers[layer]])+self.bias[self.layers[layer]]
        else:
            
            dw=np.dot(self.hidden[self.layers[layer-1]].T,self.grad[self.layers[layer+1]])/self.hidden[self.layers[layer-1]].shape[0]

            db=self.grad[self.layers[layer+1]].sum(axis=0)/self.hidden[self.layers[layer]].shape[0]

            self.grad[self.layers[layer]]=np.dot(self.grad[self.layers[layer+1]],self.weights[self.layers[layer]].T)
            
            #print("dw=",dw)
            #print("db=",db)
            
            #print("dense=",self.grad[self.layers[layer]])
            self.weights[self.layers[layer]]-=self.alpha*dw
            self.bias[self.layers[layer]]-=self.alpha*db

    
    def flatten_layer(self,layer,grad):

        x=self.hidden[self.layers[layer-1]]
   
        if grad==False:
            self.hidden[self.layers[layer]]=x.reshape(x.shape[0],x.shape[1]*x.shape[2]*x.shape[3])
        else:
            
            self.grad[self.layers[layer]]=self.grad[self.layers[layer+1]].reshape(x.shape[0],x.shape[1],x.shape[2],x.shape[3])
    
        
    def relu_layer(self,layer,grad):
        if grad==False:
            self.hidden[self.layers[layer]]=self.hidden[self.layers[layer-1]].copy()
            self.hidden[self.layers[layer]][self.hidden[self.layers[layer]]<0]=0.
        else:
            self.grad[self.layers[layer]]=self.grad[self.layers[layer+1]].copy()
            self.grad[self.layers[layer]][self.hidden[self.layers[layer]]<0]=0.    
                
        
    def sigmoid_layer(self,layer,grad):
        if grad==False:
            #print("sigmoid_shape=",(1/(1+np.exp(-self.hidden[self.layers[layer-1]]))).shape)
            self.hidden[self.layers[layer]]=1/(1+np.exp(-self.hidden[self.layers[layer-1]]))
        else:
            self.grad[self.layers[layer]]=self.hidden[self.layers[layer]]*(1-self.hidden[self.layers[layer]])*self.grad[self.layers[layer+1]]
       
        
    def softmax_layer(self,layer,grad):
        if grad==False:
            shape=self.hidden[self.layers[layer-1]].shape[0]
            
            self.hidden[self.layers[layer]]=np.exp(self.hidden[self.layers[layer-1]])/np.sum(np.exp(self.hidden[self.layers[layer-1]]),axis=1).reshape(shape,1)
            #print(self.hidden[self.layers[layer]].sum(axis=1))
        else:
            self.grad[self.layers[layer]]=self.hidden[self.layers[layer]]*(1-self.hidden[self.layers[layer]])*self.grad[self.layers[layer+1]]
    
    
    
    def cross_entropy_loss(self,layer,grad,y):
        if grad==False:
            
            self.hidden[self.layers[layer]]=np.sum(-np.log(self.hidden[self.layers[layer-1]])*self.hidden[self.layers[layer-1]],axis=1)
           
        else:
            
            self.grad[self.layers[layer]]=-(1/self.hidden[self.layers[layer]][np.argmax(y,axis=1)]).reshape(y.shape[0],1)*y
           
            
                        
   

    #initialization

                        
    def input_layer(self,size):
        i="input_"+str(self.count)
        self.layers.append(i)
        self.layers_shape[i]=(size)
        self.count=self.count+1
    
    
    
    
    def conv2d(self,kernel,number,stride,padding):
        i="conv2d_"+str(self.count)
        self.layers.append(i)
        
         
        shape=(kernel[0],kernel[1],self.layers_shape[self.layers[self.count-1]][2],number)
        self.weights[i]=np.random.normal(loc=0.0, scale=1.0, size=shape[0]*shape[1]*shape[2]*shape[3]).reshape(shape[0],shape[1],shape[2],shape[3])
       
       
        self.bias[i]=np.zeros((1,number))
        self.stride[i]=stride
        self.padding[i]=padding

        if padding=="valid":
            shapex=(int)((self.layers_shape[self.layers[self.count-1]][0]-self.weights[i].shape[0])/self.stride[i][0])+1
            shapey=(int)((self.layers_shape[self.layers[self.count-1]][1]-self.weights[i].shape[1])/self.stride[i][1])+1
        else:
            shapex=self.layers_shape[self.layers[self.count-1]][0]
            shapey=self.layers_shape[self.layers[self.count-1]][1]
        self.layers_shape[i]=([shapex,shapey,number])
        
        self.count=self.count+1
        
        
                        
    def maxpool2d(self,window,stride):
        i="maxpool2d_"+str(self.count)
        self.layers.append(i)
        
        self.window[i]=window
        self.stride[i]=stride
    
        shapex=(int)((self.layers_shape[self.layers[self.count-1]][0]-self.window[i][0])/self.stride[i][0])+1
        shapey=(int)((self.layers_shape[self.layers[self.count-1]][1]-self.window[i][1]+1)/self.stride[i][1])+1
        
        self.layers_shape[i]=([shapex,shapey,self.layers_shape[self.layers[self.count-1]][2]])
        self.count=self.count+1
        
                        
                        
    def avgpool2d(self,window,stride):
        i="avgpool2d_"+str(self.count)
        self.layers.append(i)
        
        self.window[i]=window
        self.stride[i]=stride
    
        shapex=(int)((self.layers_shape[self.layers[self.count-1]][0]-self.window[i][0])/self.stride[i][0])+1
        shapey=(int)((self.layers_shape[self.layers[self.count-1]][1]-self.window[i][1]+1)/self.stride[i][1])+1
        
        self.layers_shape[i]=([shapex,shapey,self.layers_shape[self.layers[self.count-1]][2]])
        self.count=self.count+1
        
        
        
        
    def dense(self,size):
        i="dense_"+str(self.count)
        self.layers.append(i)
        
        self.weights[i]=np.random.normal(loc=0.0, scale=1.0, size=self.layers_shape[self.layers[self.count-1]]*size).reshape(self.layers_shape[self.layers[self.count-1]],size)
        
    
                    
        self.bias[i]=np.zeros((1,size))
        self.layers_shape[i]=(size)
        self.count=self.count+1
                        
    def flatten(self):
        
        i="flatten_"+str(self.count)
        self.layers.append(i)
        size=self.layers_shape[self.layers[self.count-1]][0]*self.layers_shape[self.layers[self.count-1]][1]*self.layers_shape[self.layers[self.count-1]][2]
        self.layers_shape[i]=(size)
        self.count=self.count+1
    
    def relu(self):
        i="relu_"+str(self.count)
        self.layers.append(i)
        self.layers_shape[i]=(self.layers_shape[self.layers[self.count-1]])
        self.count=self.count+1
    
    def sigmoid(self):
        i="sigmoid_"+str(self.count)
        self.layers.append(i)
        self.layers_shape[i]=(self.layers_shape[self.layers[self.count-1]])
        self.count=self.count+1
                        
    def softmax(self):
        i="softmax_"+str(self.count)
        self.layers.append(i)
        self.layers_shape[i]=(self.layers_shape[self.layers[self.count-1]])
        self.count=self.count+1
        
    def crossentropy(self):
        i="crossentropy_"+str(self.count)
        self.layers.append(i)
        self.layers_shape[i]=1
        self.count=self.count+1
        
        
        
    def summary(self):
    
        for i in self.layers:
            print("name:",i)
            print("layer_shape",":",self.layers_shape[i])
            try:
                print("stride:",self.stride[i])
                print("kernel:",self.weights[i].shape)
                print("padding:",self.padding[i])
            except Exception as e:
                print(e)
                try:
                    print("window:",self.window[i].shape)
                except:
                    b=2
            print("")

# %%
n_classes=10
a = np.arange(n_classes)
b = np.zeros((n_classes, n_classes))
b[np.arange(n_classes), a] = 1


x=xtrain.reshape(xtrain.shape[0],28,28,1)
y=b[ytrain]

print(x.shape,y.shape)
classifier=CNN(0.01)

classifier.input_layer([x.shape[1],x.shape[2],x.shape[3]])
classifier.conv2d(kernel=(3,3),number=5,stride=(1,1),padding='same')
classifier.relu()
classifier.maxpool2d(window=(2,2),stride=(2,2))
classifier.conv2d(kernel=(3,3),number=10,stride=(2,2),padding='same')
classifier.relu()
classifier.maxpool2d(window=(2,2),stride=(2,2))
classifier.flatten()
classifier.dense(5)
classifier.sigmoid()

classifier.dense(10)
classifier.softmax()
classifier.crossentropy()
print(classifier.summary())

classifier.fit(x,y,batch_size=100,epoch=10)

#print(classifier.predict(x,y))
# Out:
# (60000, 28, 28, 1) (60000, 10)
# name: input_0
# layer_shape : [28, 28, 1]
# 'input_0'
#
# name: conv2d_1
# layer_shape : [28, 28, 5]
# stride: (1, 1)
# kernel: (3, 3, 1, 5)
# padding: same
#
# name: relu_2
# layer_shape : [28, 28, 5]
# 'relu_2'
#
# name: maxpool2d_3
# layer_shape : [14, 14, 5]
# stride: (2, 2)
# 'maxpool2d_3'
#
# name: conv2d_4
# layer_shape : [14, 14, 10]
# stride: (2, 2)
# kernel: (3, 3, 5, 10)
# padding: same
#
# name: relu_5
# layer_shape : [14, 14, 10]
# 'relu_5'
#
# name: maxpool2d_6
# layer_shape : [7, 7, 10]
# stride: (2, 2)
# 'maxpool2d_6'
#
# name: flatten_7
# layer_shape : 490
# 'flatten_7'
#
# name: dense_8
# layer_shape : 5
# 'dense_8'
#
# name: sigmoid_9
# layer_shape : 5
# 'sigmoid_9'
#
# name: dense_10
# layer_shape : 10
# 'dense_10'
#
# name: softmax_11
# layer_shape : 10
# 'softmax_11'
#
# name: crossentropy_12
# layer_shape : 1
# 'crossentropy_12'
#
# None
# C:\Users\asus\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:420: RuntimeWarning: overflow encountered in exp
# C:\Users\asus\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:281: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# epoch= 0  step= 0  accuracy= 0.11
# epoch= 0  step= 1  accuracy= 0.06
# epoch= 0  step= 2  accuracy= 0.07
# epoch= 0  step= 3  accuracy= 0.12
# epoch= 0  step= 4  accuracy= 0.14
# epoch= 0  step= 5  accuracy= 0.1
# epoch= 0  step= 6  accuracy= 0.08
# epoch= 0  step= 7  accuracy= 0.08
# epoch= 0  step= 8  accuracy= 0.11
# epoch= 0  step= 9  accuracy= 0.16
# epoch= 0  step= 10  accuracy= 0.16
# epoch= 0  step= 11  accuracy= 0.11
# epoch= 0  step= 12  accuracy= 0.12
# epoch= 0  step= 13  accuracy= 0.09
# epoch= 0  step= 14  accuracy= 0.13
# epoch= 0  step= 15  accuracy= 0.08
# epoch= 0  step= 16  accuracy= 0.1
# epoch= 0  step= 17  accuracy= 0.12
# epoch= 0  step= 18  accuracy= 0.12
# epoch= 0  step= 19  accuracy= 0.04
# epoch= 0  step= 20  accuracy= 0.06
# epoch= 0  step= 21  accuracy= 0.12
# epoch= 0  step= 22  accuracy= 0.08
# epoch= 0  step= 23  accuracy= 0.12
# epoch= 0  step= 24  accuracy= 0.17
# epoch= 0  step= 25  accuracy= 0.13
# epoch= 0  step= 26  accuracy= 0.09
# epoch= 0  step= 27  accuracy= 0.08
# epoch= 0  step= 28  accuracy= 0.13
# epoch= 0  step= 29  accuracy= 0.13
# epoch= 0  step= 30  accuracy= 0.07
# epoch= 0  step= 31  accuracy= 0.11
# epoch= 0  step= 32  accuracy= 0.06
# epoch= 0  step= 33  accuracy= 0.07
# epoch= 0  step= 34  accuracy= 0.16
# epoch= 0  step= 35  accuracy= 0.11
# epoch= 0  step= 36  accuracy= 0.08
# epoch= 0  step= 37  accuracy= 0.16
# epoch= 0  step= 38  accuracy= 0.13
# epoch= 0  step= 39  accuracy= 0.11
# epoch= 0  step= 40  accuracy= 0.13
# epoch= 0  step= 41  accuracy= 0.1
# epoch= 0  step= 42  accuracy= 0.13
# epoch= 0  step= 43  accuracy= 0.14
# epoch= 0  step= 44  accuracy= 0.12
# epoch= 0  step= 45  accuracy= 0.12
# epoch= 0  step= 46  accuracy= 0.09
# epoch= 0  step= 47  accuracy= 0.07
# epoch= 0  step= 48  accuracy= 0.13
# epoch= 0  step= 49  accuracy= 0.08
# epoch= 0  step= 50  accuracy= 0.09
# epoch= 0  step= 51  accuracy= 0.08
# epoch= 0  step= 52  accuracy= 0.08
# epoch= 0  step= 53  accuracy= 0.08
# epoch= 0  step= 54  accuracy= 0.09
# epoch= 0  step= 55  accuracy= 0.09
# epoch= 0  step= 56  accuracy= 0.1
# epoch= 0  step= 57  accuracy= 0.1
# epoch= 0  step= 58  accuracy= 0.09
# epoch= 0  step= 59  accuracy= 0.13
# epoch= 0  step= 60  accuracy= 0.08
# epoch= 0  step= 61  accuracy= 0.11
# epoch= 0  step= 62  accuracy= 0.12
# epoch= 0  step= 63  accuracy= 0.15
# epoch= 0  step= 64  accuracy= 0.08
# epoch= 0  step= 65  accuracy= 0.08
# epoch= 0  step= 66  accuracy= 0.09
# epoch= 0  step= 67  accuracy= 0.14
# epoch= 0  step= 68  accuracy= 0.16
# epoch= 0  step= 69  accuracy= 0.1
# epoch= 0  step= 70  accuracy= 0.14
# epoch= 0  step= 71  accuracy= 0.1
# epoch= 0  step= 72  accuracy= 0.11
# epoch= 0  step= 73  accuracy= 0.09
# epoch= 0  step= 74  accuracy= 0.12
# epoch= 0  step= 75  accuracy= 0.09
# epoch= 0  step= 76  accuracy= 0.17
# epoch= 0  step= 77  accuracy= 0.11
# epoch= 0  step= 78  accuracy= 0.12
# epoch= 0  step= 79  accuracy= 0.11
# epoch= 0  step= 80  accuracy= 0.11
# epoch= 0  step= 81  accuracy= 0.14
# epoch= 0  step= 82  accuracy= 0.09
# epoch= 0  step= 83  accuracy= 0.06
# epoch= 0  step= 84  accuracy= 0.08
# epoch= 0  step= 85  accuracy= 0.1
# epoch= 0  step= 86  accuracy= 0.14
# epoch= 0  step= 87  accuracy= 0.13
# epoch= 0  step= 88  accuracy= 0.09
# epoch= 0  step= 89  accuracy= 0.12
# epoch= 0  step= 90  accuracy= 0.07
# epoch= 0  step= 91  accuracy= 0.1
# epoch= 0  step= 92  accuracy= 0.1
# epoch= 0  step= 93  accuracy= 0.06
# epoch= 0  step= 94  accuracy= 0.1
# epoch= 0  step= 95  accuracy= 0.15
# epoch= 0  step= 96  accuracy= 0.11
# epoch= 0  step= 97  accuracy= 0.1
# epoch= 0  step= 98  accuracy= 0.08
# epoch= 0  step= 99  accuracy= 0.11
# epoch= 0  step= 100  accuracy= 0.07
# epoch= 0  step= 101  accuracy= 0.11
# epoch= 0  step= 102  accuracy= 0.13
# epoch= 0  step= 103  accuracy= 0.11
# epoch= 0  step= 104  accuracy= 0.06
# epoch= 0  step= 105  accuracy= 0.07
# epoch= 0  step= 106  accuracy= 0.07
# epoch= 0  step= 107  accuracy= 0.11
# epoch= 0  step= 108  accuracy= 0.06
# epoch= 0  step= 109  accuracy= 0.12
# epoch= 0  step= 110  accuracy= 0.12
# epoch= 0  step= 111  accuracy= 0.14
# epoch= 0  step= 112  accuracy= 0.16
# epoch= 0  step= 113  accuracy= 0.12
# epoch= 0  step= 114  accuracy= 0.06
# epoch= 0  step= 115  accuracy= 0.14
# epoch= 0  step= 116  accuracy= 0.07
# epoch= 0  step= 117  accuracy= 0.07
# epoch= 0  step= 118  accuracy= 0.13
# epoch= 0  step= 119  accuracy= 0.1
# epoch= 0  step= 120  accuracy= 0.07
# epoch= 0  step= 121  accuracy= 0.12
# epoch= 0  step= 122  accuracy= 0.2
# epoch= 0  step= 123  accuracy= 0.14
# epoch= 0  step= 124  accuracy= 0.15
# epoch= 0  step= 125  accuracy= 0.11
# epoch= 0  step= 126  accuracy= 0.1
# epoch= 0  step= 127  accuracy= 0.1
# epoch= 0  step= 128  accuracy= 0.07
# epoch= 0  step= 129  accuracy= 0.05
# epoch= 0  step= 130  accuracy= 0.11
# epoch= 0  step= 131  accuracy= 0.1
# epoch= 0  step= 132  accuracy= 0.09
# epoch= 0  step= 133  accuracy= 0.08
# epoch= 0  step= 134  accuracy= 0.09
# epoch= 0  step= 135  accuracy= 0.06
# epoch= 0  step= 136  accuracy= 0.1
# epoch= 0  step= 137  accuracy= 0.1
# epoch= 0  step= 138  accuracy= 0.11
# epoch= 0  step= 139  accuracy= 0.09
# epoch= 0  step= 140  accuracy= 0.12
# epoch= 0  step= 141  accuracy= 0.09
# epoch= 0  step= 142  accuracy= 0.08
# epoch= 0  step= 143  accuracy= 0.09
# epoch= 0  step= 144  accuracy= 0.06
# epoch= 0  step= 145  accuracy= 0.13
# epoch= 0  step= 146  accuracy= 0.12
# epoch= 0  step= 147  accuracy= 0.06
# epoch= 0  step= 148  accuracy= 0.12
# epoch= 0  step= 149  accuracy= 0.11
# epoch= 0  step= 150  accuracy= 0.04
# epoch= 0  step= 151  accuracy= 0.08
# epoch= 0  step= 152  accuracy= 0.23
# epoch= 0  step= 153  accuracy= 0.06
# epoch= 0  step= 154  accuracy= 0.12
# epoch= 0  step= 155  accuracy= 0.15
# epoch= 0  step= 156  accuracy= 0.11
# epoch= 0  step= 157  accuracy= 0.09
# epoch= 0  step= 158  accuracy= 0.09
# epoch= 0  step= 159  accuracy= 0.09
# epoch= 0  step= 160  accuracy= 0.07
# epoch= 0  step= 161  accuracy= 0.14
# epoch= 0  step= 162  accuracy= 0.11
# epoch= 0  step= 163  accuracy= 0.14
# epoch= 0  step= 164  accuracy= 0.07
# epoch= 0  step= 165  accuracy= 0.08
# epoch= 0  step= 166  accuracy= 0.05
# epoch= 0  step= 167  accuracy= 0.06
# epoch= 0  step= 168  accuracy= 0.09
# epoch= 0  step= 169  accuracy= 0.06
# epoch= 0  step= 170  accuracy= 0.06
# epoch= 0  step= 171  accuracy= 0.14
# epoch= 0  step= 172  accuracy= 0.14
# epoch= 0  step= 173  accuracy= 0.12
# epoch= 0  step= 174  accuracy= 0.16
# epoch= 0  step= 175  accuracy= 0.09
# epoch= 0  step= 176  accuracy= 0.1
# epoch= 0  step= 177  accuracy= 0.1
# epoch= 0  step= 178  accuracy= 0.11
# epoch= 0  step= 179  accuracy= 0.05
# epoch= 0  step= 180  accuracy= 0.1
# epoch= 0  step= 181  accuracy= 0.11
# epoch= 0  step= 182  accuracy= 0.13
# epoch= 0  step= 183  accuracy= 0.1
# epoch= 0  step= 184  accuracy= 0.09
# epoch= 0  step= 185  accuracy= 0.08
# epoch= 0  step= 186  accuracy= 0.09
# epoch= 0  step= 187  accuracy= 0.11
# epoch= 0  step= 188  accuracy= 0.1
# epoch= 0  step= 189  accuracy= 0.09
# epoch= 0  step= 190  accuracy= 0.08
# epoch= 0  step= 191  accuracy= 0.09
# epoch= 0  step= 192  accuracy= 0.12
# epoch= 0  step= 193  accuracy= 0.1
# epoch= 0  step= 194  accuracy= 0.08
# epoch= 0  step= 195  accuracy= 0.12
# epoch= 0  step= 196  accuracy= 0.09
# epoch= 0  step= 197  accuracy= 0.06
# epoch= 0  step= 198  accuracy= 0.13
# epoch= 0  step= 199  accuracy= 0.03
# epoch= 0  step= 200  accuracy= 0.08
# epoch= 0  step= 201  accuracy= 0.06
# epoch= 0  step= 202  accuracy= 0.1
# epoch= 0  step= 203  accuracy= 0.13
# epoch= 0  step= 204  accuracy= 0.08
# epoch= 0  step= 205  accuracy= 0.09
# epoch= 0  step= 206  accuracy= 0.05
# epoch= 0  step= 207  accuracy= 0.07
# epoch= 0  step= 208  accuracy= 0.08
# epoch= 0  step= 209  accuracy= 0.03
# epoch= 0  step= 210  accuracy= 0.09
# epoch= 0  step= 211  accuracy= 0.11
# epoch= 0  step= 212  accuracy= 0.09
# epoch= 0  step= 213  accuracy= 0.13
# epoch= 0  step= 214  accuracy= 0.1
# epoch= 0  step= 215  accuracy= 0.06
# epoch= 0  step= 216  accuracy= 0.07
# epoch= 0  step= 217  accuracy= 0.15
# epoch= 0  step= 218  accuracy= 0.12
# epoch= 0  step= 219  accuracy= 0.12
# epoch= 0  step= 220  accuracy= 0.09
# epoch= 0  step= 221  accuracy= 0.1
# epoch= 0  step= 222  accuracy= 0.04
# epoch= 0  step= 223  accuracy= 0.1
# epoch= 0  step= 224  accuracy= 0.12
# epoch= 0  step= 225  accuracy= 0.11
# epoch= 0  step= 226  accuracy= 0.07
# epoch= 0  step= 227  accuracy= 0.02
# epoch= 0  step= 228  accuracy= 0.13
# epoch= 0  step= 229  accuracy= 0.07
# epoch= 0  step= 230  accuracy= 0.15
# epoch= 0  step= 231  accuracy= 0.1
# epoch= 0  step= 232  accuracy= 0.11
# epoch= 0  step= 233  accuracy= 0.09
# epoch= 0  step= 234  accuracy= 0.09
# epoch= 0  step= 235  accuracy= 0.08
# epoch= 0  step= 236  accuracy= 0.04
# epoch= 0  step= 237  accuracy= 0.11
# epoch= 0  step= 238  accuracy= 0.08
# epoch= 0  step= 239  accuracy= 0.09
# epoch= 0  step= 240  accuracy= 0.08
# epoch= 0  step= 241  accuracy= 0.11
# epoch= 0  step= 242  accuracy= 0.1
# epoch= 0  step= 243  accuracy= 0.13
# epoch= 0  step= 244  accuracy= 0.13
# epoch= 0  step= 245  accuracy= 0.12
# epoch= 0  step= 246  accuracy= 0.15
# epoch= 0  step= 247  accuracy= 0.08
# epoch= 0  step= 248  accuracy= 0.15
# epoch= 0  step= 249  accuracy= 0.1
# epoch= 0  step= 250  accuracy= 0.1
# epoch= 0  step= 251  accuracy= 0.15
# epoch= 0  step= 252  accuracy= 0.1
# epoch= 0  step= 253  accuracy= 0.2
# epoch= 0  step= 254  accuracy= 0.11
# epoch= 0  step= 255  accuracy= 0.11
# epoch= 0  step= 256  accuracy= 0.08
# epoch= 0  step= 257  accuracy= 0.15
# epoch= 0  step= 258  accuracy= 0.19
# epoch= 0  step= 259  accuracy= 0.09
# epoch= 0  step= 260  accuracy= 0.08
# epoch= 0  step= 261  accuracy= 0.09
# epoch= 0  step= 262  accuracy= 0.15
# epoch= 0  step= 263  accuracy= 0.05
# epoch= 0  step= 264  accuracy= 0.12
# epoch= 0  step= 265  accuracy= 0.13
# epoch= 0  step= 266  accuracy= 0.05
# epoch= 0  step= 267  accuracy= 0.07
# epoch= 0  step= 268  accuracy= 0.03
# epoch= 0  step= 269  accuracy= 0.11
# epoch= 0  step= 270  accuracy= 0.16
# epoch= 0  step= 271  accuracy= 0.1
# epoch= 0  step= 272  accuracy= 0.1
# epoch= 0  step= 273  accuracy= 0.03
# epoch= 0  step= 274  accuracy= 0.06
# epoch= 0  step= 275  accuracy= 0.07
# epoch= 0  step= 276  accuracy= 0.08
# epoch= 0  step= 277  accuracy= 0.15
# epoch= 0  step= 278  accuracy= 0.14
# epoch= 0  step= 279  accuracy= 0.11
# epoch= 0  step= 280  accuracy= 0.07
# epoch= 0  step= 281  accuracy= 0.12
# epoch= 0  step= 282  accuracy= 0.12
# epoch= 0  step= 283  accuracy= 0.05
# epoch= 0  step= 284  accuracy= 0.08
# epoch= 0  step= 285  accuracy= 0.08
# epoch= 0  step= 286  accuracy= 0.13
# epoch= 0  step= 287  accuracy= 0.09
# epoch= 0  step= 288  accuracy= 0.08
# epoch= 0  step= 289  accuracy= 0.12
# epoch= 0  step= 290  accuracy= 0.08
# epoch= 0  step= 291  accuracy= 0.11
# epoch= 0  step= 292  accuracy= 0.15
# epoch= 0  step= 293  accuracy= 0.1
# epoch= 0  step= 294  accuracy= 0.12
# epoch= 0  step= 295  accuracy= 0.11
# epoch= 0  step= 296  accuracy= 0.17
# epoch= 0  step= 297  accuracy= 0.1
# epoch= 0  step= 298  accuracy= 0.09
# epoch= 0  step= 299  accuracy= 0.1
# epoch= 0  step= 300  accuracy= 0.08
# epoch= 0  step= 301  accuracy= 0.09
# epoch= 0  step= 302  accuracy= 0.05
# epoch= 0  step= 303  accuracy= 0.06
# epoch= 0  step= 304  accuracy= 0.11
# epoch= 0  step= 305  accuracy= 0.16
# epoch= 0  step= 306  accuracy= 0.09
# epoch= 0  step= 307  accuracy= 0.11
# epoch= 0  step= 308  accuracy= 0.05
# epoch= 0  step= 309  accuracy= 0.1
# epoch= 0  step= 310  accuracy= 0.09
# epoch= 0  step= 311  accuracy= 0.09
# epoch= 0  step= 312  accuracy= 0.14
# epoch= 0  step= 313  accuracy= 0.14
# epoch= 0  step= 314  accuracy= 0.1
# epoch= 0  step= 315  accuracy= 0.15
# epoch= 0  step= 316  accuracy= 0.05
# epoch= 0  step= 317  accuracy= 0.1
# epoch= 0  step= 318  accuracy= 0.08
# epoch= 0  step= 319  accuracy= 0.08
# epoch= 0  step= 320  accuracy= 0.09
# epoch= 0  step= 321  accuracy= 0.15
# epoch= 0  step= 322  accuracy= 0.09
# epoch= 0  step= 323  accuracy= 0.13
# epoch= 0  step= 324  accuracy= 0.09
# epoch= 0  step= 325  accuracy= 0.08
# epoch= 0  step= 326  accuracy= 0.05
# epoch= 0  step= 327  accuracy= 0.1
# epoch= 0  step= 328  accuracy= 0.1
# epoch= 0  step= 329  accuracy= 0.08
# epoch= 0  step= 330  accuracy= 0.1
# epoch= 0  step= 331  accuracy= 0.03
# epoch= 0  step= 332  accuracy= 0.04
# epoch= 0  step= 333  accuracy= 0.11
# epoch= 0  step= 334  accuracy= 0.11
# epoch= 0  step= 335  accuracy= 0.07
# epoch= 0  step= 336  accuracy= 0.1
# epoch= 0  step= 337  accuracy= 0.09
# epoch= 0  step= 338  accuracy= 0.11
# epoch= 0  step= 339  accuracy= 0.08
# epoch= 0  step= 340  accuracy= 0.12
# epoch= 0  step= 341  accuracy= 0.07
# epoch= 0  step= 342  accuracy= 0.08
# epoch= 0  step= 343  accuracy= 0.09
# epoch= 0  step= 344  accuracy= 0.08
# epoch= 0  step= 345  accuracy= 0.13
# epoch= 0  step= 346  accuracy= 0.11
# epoch= 0  step= 347  accuracy= 0.13
# epoch= 0  step= 348  accuracy= 0.07
# epoch= 0  step= 349  accuracy= 0.12
# epoch= 0  step= 350  accuracy= 0.1
# epoch= 0  step= 351  accuracy= 0.08
# epoch= 0  step= 352  accuracy= 0.11
# epoch= 0  step= 353  accuracy= 0.14
# epoch= 0  step= 354  accuracy= 0.08
# epoch= 0  step= 355  accuracy= 0.11
# epoch= 0  step= 356  accuracy= 0.11
# epoch= 0  step= 357  accuracy= 0.12
# epoch= 0  step= 358  accuracy= 0.02
# epoch= 0  step= 359  accuracy= 0.17
# epoch= 0  step= 360  accuracy= 0.16
# epoch= 0  step= 361  accuracy= 0.13
# epoch= 0  step= 362  accuracy= 0.11
# epoch= 0  step= 363  accuracy= 0.09
# epoch= 0  step= 364  accuracy= 0.14
# epoch= 0  step= 365  accuracy= 0.07
# epoch= 0  step= 366  accuracy= 0.13
# epoch= 0  step= 367  accuracy= 0.1
# epoch= 0  step= 368  accuracy= 0.07
# epoch= 0  step= 369  accuracy= 0.09
# epoch= 0  step= 370  accuracy= 0.06
# epoch= 0  step= 371  accuracy= 0.08
# epoch= 0  step= 372  accuracy= 0.06
# epoch= 0  step= 373  accuracy= 0.06
# epoch= 0  step= 374  accuracy= 0.09
# epoch= 0  step= 375  accuracy= 0.01
# epoch= 0  step= 376  accuracy= 0.06
# epoch= 0  step= 377  accuracy= 0.08
# epoch= 0  step= 378  accuracy= 0.11
# epoch= 0  step= 379  accuracy= 0.08
# epoch= 0  step= 380  accuracy= 0.06
# epoch= 0  step= 381  accuracy= 0.07
# epoch= 0  step= 382  accuracy= 0.14
# epoch= 0  step= 383  accuracy= 0.06
# epoch= 0  step= 384  accuracy= 0.13
# epoch= 0  step= 385  accuracy= 0.14
# epoch= 0  step= 386  accuracy= 0.13
# epoch= 0  step= 387  accuracy= 0.12
# epoch= 0  step= 388  accuracy= 0.1
# epoch= 0  step= 389  accuracy= 0.1
# epoch= 0  step= 390  accuracy= 0.1
# epoch= 0  step= 391  accuracy= 0.1
# epoch= 0  step= 392  accuracy= 0.08
# epoch= 0  step= 393  accuracy= 0.11
# epoch= 0  step= 394  accuracy= 0.06
# epoch= 0  step= 395  accuracy= 0.05
# epoch= 0  step= 396  accuracy= 0.05
# epoch= 0  step= 397  accuracy= 0.1
# epoch= 0  step= 398  accuracy= 0.12
# epoch= 0  step= 399  accuracy= 0.1
# epoch= 0  step= 400  accuracy= 0.13
# epoch= 0  step= 401  accuracy= 0.07
# epoch= 0  step= 402  accuracy= 0.09
# epoch= 0  step= 403  accuracy= 0.14
# epoch= 0  step= 404  accuracy= 0.09
# epoch= 0  step= 405  accuracy= 0.14
# epoch= 0  step= 406  accuracy= 0.09
# epoch= 0  step= 407  accuracy= 0.12
# epoch= 0  step= 408  accuracy= 0.06
# epoch= 0  step= 409  accuracy= 0.05
# epoch= 0  step= 410  accuracy= 0.06
# epoch= 0  step= 411  accuracy= 0.12
# epoch= 0  step= 412  accuracy= 0.1
# epoch= 0  step= 413  accuracy= 0.11
# epoch= 0  step= 414  accuracy= 0.11
# epoch= 0  step= 415  accuracy= 0.13
# epoch= 0  step= 416  accuracy= 0.06
# epoch= 0  step= 417  accuracy= 0.09
# epoch= 0  step= 418  accuracy= 0.07
# epoch= 0  step= 419  accuracy= 0.08
# epoch= 0  step= 420  accuracy= 0.09
# epoch= 0  step= 421  accuracy= 0.14
# epoch= 0  step= 422  accuracy= 0.14
# epoch= 0  step= 423  accuracy= 0.08
# epoch= 0  step= 424  accuracy= 0.09
# epoch= 0  step= 425  accuracy= 0.12
# epoch= 0  step= 426  accuracy= 0.12
# epoch= 0  step= 427  accuracy= 0.13
# epoch= 0  step= 428  accuracy= 0.1
# epoch= 0  step= 429  accuracy= 0.12
# epoch= 0  step= 430  accuracy= 0.19
# epoch= 0  step= 431  accuracy= 0.07
# epoch= 0  step= 432  accuracy= 0.1
# epoch= 0  step= 433  accuracy= 0.11
# epoch= 0  step= 434  accuracy= 0.07
# epoch= 0  step= 435  accuracy= 0.1
# epoch= 0  step= 436  accuracy= 0.06
# epoch= 0  step= 437  accuracy= 0.13
# epoch= 0  step= 438  accuracy= 0.11
# epoch= 0  step= 439  accuracy= 0.14
# epoch= 0  step= 440  accuracy= 0.08
# epoch= 0  step= 441  accuracy= 0.1
# epoch= 0  step= 442  accuracy= 0.11
# epoch= 0  step= 443  accuracy= 0.06
# epoch= 0  step= 444  accuracy= 0.12
# epoch= 0  step= 445  accuracy= 0.09
# epoch= 0  step= 446  accuracy= 0.1
# epoch= 0  step= 447  accuracy= 0.04
# epoch= 0  step= 448  accuracy= 0.1
# epoch= 0  step= 449  accuracy= 0.12
# epoch= 0  step= 450  accuracy= 0.13
# epoch= 0  step= 451  accuracy= 0.09
# epoch= 0  step= 452  accuracy= 0.06
# epoch= 0  step= 453  accuracy= 0.04
# epoch= 0  step= 454  accuracy= 0.08
# epoch= 0  step= 455  accuracy= 0.07
# epoch= 0  step= 456  accuracy= 0.04
# epoch= 0  step= 457  accuracy= 0.09
# epoch= 0  step= 458  accuracy= 0.09
# epoch= 0  step= 459  accuracy= 0.1
# epoch= 0  step= 460  accuracy= 0.13
# epoch= 0  step= 461  accuracy= 0.11
# epoch= 0  step= 462  accuracy= 0.09
# epoch= 0  step= 463  accuracy= 0.06
# epoch= 0  step= 464  accuracy= 0.06
# epoch= 0  step= 465  accuracy= 0.08
# epoch= 0  step= 466  accuracy= 0.11
# epoch= 0  step= 467  accuracy= 0.08
# epoch= 0  step= 468  accuracy= 0.11
# epoch= 0  step= 469  accuracy= 0.11
# epoch= 0  step= 470  accuracy= 0.15
# epoch= 0  step= 471  accuracy= 0.1
# epoch= 0  step= 472  accuracy= 0.1
# epoch= 0  step= 473  accuracy= 0.1
# epoch= 0  step= 474  accuracy= 0.08
# epoch= 0  step= 475  accuracy= 0.08
# epoch= 0  step= 476  accuracy= 0.14
# epoch= 0  step= 477  accuracy= 0.05
# epoch= 0  step= 478  accuracy= 0.09
# epoch= 0  step= 479  accuracy= 0.08
# epoch= 0  step= 480  accuracy= 0.11
# epoch= 0  step= 481  accuracy= 0.09
# epoch= 0  step= 482  accuracy= 0.08
# epoch= 0  step= 483  accuracy= 0.13
# epoch= 0  step= 484  accuracy= 0.1
# epoch= 0  step= 485  accuracy= 0.12
# epoch= 0  step= 486  accuracy= 0.11
# epoch= 0  step= 487  accuracy= 0.15
# epoch= 0  step= 488  accuracy= 0.07
# epoch= 0  step= 489  accuracy= 0.14
# epoch= 0  step= 490  accuracy= 0.04
# epoch= 0  step= 491  accuracy= 0.11
# epoch= 0  step= 492  accuracy= 0.1
# epoch= 0  step= 493  accuracy= 0.08
# epoch= 0  step= 494  accuracy= 0.06
# epoch= 0  step= 495  accuracy= 0.13
# epoch= 0  step= 496  accuracy= 0.07
# epoch= 0  step= 497  accuracy= 0.06
# epoch= 0  step= 498  accuracy= 0.02
# epoch= 0  step= 499  accuracy= 0.07
# epoch= 0  step= 500  accuracy= 0.07
# epoch= 0  step= 501  accuracy= 0.07
# epoch= 0  step= 502  accuracy= 0.12
# epoch= 0  step= 503  accuracy= 0.06
# epoch= 0  step= 504  accuracy= 0.1
# epoch= 0  step= 505  accuracy= 0.04
# epoch= 0  step= 506  accuracy= 0.08
# epoch= 0  step= 507  accuracy= 0.18
# epoch= 0  step= 508  accuracy= 0.11
# epoch= 0  step= 509  accuracy= 0.1
# epoch= 0  step= 510  accuracy= 0.1
# epoch= 0  step= 511  accuracy= 0.06
# epoch= 0  step= 512  accuracy= 0.07
# epoch= 0  step= 513  accuracy= 0.1
# epoch= 0  step= 514  accuracy= 0.05
# epoch= 0  step= 515  accuracy= 0.04
# epoch= 0  step= 516  accuracy= 0.05
# epoch= 0  step= 517  accuracy= 0.11
# epoch= 0  step= 518  accuracy= 0.15
# epoch= 0  step= 519  accuracy= 0.1
# epoch= 0  step= 520  accuracy= 0.13
# epoch= 0  step= 521  accuracy= 0.07
# epoch= 0  step= 522  accuracy= 0.08
# epoch= 0  step= 523  accuracy= 0.15
# epoch= 0  step= 524  accuracy= 0.12
# epoch= 0  step= 525  accuracy= 0.07
# epoch= 0  step= 526  accuracy= 0.12
# epoch= 0  step= 527  accuracy= 0.1
# epoch= 0  step= 528  accuracy= 0.15
# epoch= 0  step= 529  accuracy= 0.1
# epoch= 0  step= 530  accuracy= 0.09
# epoch= 0  step= 531  accuracy= 0.17
# epoch= 0  step= 532  accuracy= 0.09
# epoch= 0  step= 533  accuracy= 0.11
# epoch= 0  step= 534  accuracy= 0.1
# epoch= 0  step= 535  accuracy= 0.12
# epoch= 0  step= 536  accuracy= 0.1
# epoch= 0  step= 537  accuracy= 0.09
# epoch= 0  step= 538  accuracy= 0.12
# epoch= 0  step= 539  accuracy= 0.1
# epoch= 0  step= 540  accuracy= 0.13
# epoch= 0  step= 541  accuracy= 0.09
# epoch= 0  step= 542  accuracy= 0.06
# epoch= 0  step= 543  accuracy= 0.08
# epoch= 0  step= 544  accuracy= 0.05
# epoch= 0  step= 545  accuracy= 0.12
# epoch= 0  step= 546  accuracy= 0.1
# epoch= 0  step= 547  accuracy= 0.1
# epoch= 0  step= 548  accuracy= 0.09
# epoch= 0  step= 549  accuracy= 0.1
# epoch= 0  step= 550  accuracy= 0.08
# epoch= 0  step= 551  accuracy= 0.09
# epoch= 0  step= 552  accuracy= 0.11
# epoch= 0  step= 553  accuracy= 0.1
# epoch= 0  step= 554  accuracy= 0.12
# epoch= 0  step= 555  accuracy= 0.07
# epoch= 0  step= 556  accuracy= 0.1
# epoch= 0  step= 557  accuracy= 0.12
# epoch= 0  step= 558  accuracy= 0.11
# epoch= 0  step= 559  accuracy= 0.05
# epoch= 0  step= 560  accuracy= 0.19
# epoch= 0  step= 561  accuracy= 0.06
# epoch= 0  step= 562  accuracy= 0.06
# epoch= 0  step= 563  accuracy= 0.04
# epoch= 0  step= 564  accuracy= 0.08
# epoch= 0  step= 565  accuracy= 0.08
# epoch= 0  step= 566  accuracy= 0.02
# epoch= 0  step= 567  accuracy= 0.05
# epoch= 0  step= 568  accuracy= 0.12
# epoch= 0  step= 569  accuracy= 0.08
# epoch= 0  step= 570  accuracy= 0.08
# epoch= 0  step= 571  accuracy= 0.13
# epoch= 0  step= 572  accuracy= 0.12
# epoch= 0  step= 573  accuracy= 0.15
# epoch= 0  step= 574  accuracy= 0.11
# epoch= 0  step= 575  accuracy= 0.11
# epoch= 0  step= 576  accuracy= 0.18
# epoch= 0  step= 577  accuracy= 0.09
# epoch= 0  step= 578  accuracy= 0.06
# epoch= 0  step= 579  accuracy= 0.08
# epoch= 0  step= 580  accuracy= 0.14
# epoch= 0  step= 581  accuracy= 0.12
# epoch= 0  step= 582  accuracy= 0.09
# epoch= 0  step= 583  accuracy= 0.08
# epoch= 0  step= 584  accuracy= 0.11
# epoch= 0  step= 585  accuracy= 0.07
# epoch= 0  step= 586  accuracy= 0.15
# epoch= 0  step= 587  accuracy= 0.14
# epoch= 0  step= 588  accuracy= 0.13
# epoch= 0  step= 589  accuracy= 0.1
# epoch= 0  step= 590  accuracy= 0.09
# epoch= 0  step= 591  accuracy= 0.09
# epoch= 0  step= 592  accuracy= 0.12
# epoch= 0  step= 593  accuracy= 0.14
# epoch= 0  step= 594  accuracy= 0.11
# epoch= 0  step= 595  accuracy= 0.08
# epoch= 0  step= 596  accuracy= 0.07
# epoch= 0  step= 597  accuracy= 0.08
# epoch= 0  step= 598  accuracy= 0.06
# epoch= 0  step= 599  accuracy= 0.09
# epoch= 1  step= 0  accuracy= 0.12
# epoch= 1  step= 1  accuracy= 0.07
# epoch= 1  step= 2  accuracy= 0.07
# epoch= 1  step= 3  accuracy= 0.11
# epoch= 1  step= 4  accuracy= 0.11
# epoch= 1  step= 5  accuracy= 0.1
# epoch= 1  step= 6  accuracy= 0.06
# epoch= 1  step= 7  accuracy= 0.06
# epoch= 1  step= 8  accuracy= 0.13
# epoch= 1  step= 9  accuracy= 0.17
# epoch= 1  step= 10  accuracy= 0.14
# epoch= 1  step= 11  accuracy= 0.07
# epoch= 1  step= 12  accuracy= 0.11
# epoch= 1  step= 13  accuracy= 0.07
# epoch= 1  step= 14  accuracy= 0.08
# epoch= 1  step= 15  accuracy= 0.07
# epoch= 1  step= 16  accuracy= 0.14
# epoch= 1  step= 17  accuracy= 0.13
# epoch= 1  step= 18  accuracy= 0.12
# epoch= 1  step= 19  accuracy= 0.04
# epoch= 1  step= 20  accuracy= 0.07
# epoch= 1  step= 21  accuracy= 0.11
# epoch= 1  step= 22  accuracy= 0.08
# epoch= 1  step= 23  accuracy= 0.14
# epoch= 1  step= 24  accuracy= 0.14
# epoch= 1  step= 25  accuracy= 0.13
# epoch= 1  step= 26  accuracy= 0.11
# epoch= 1  step= 27  accuracy= 0.07
# epoch= 1  step= 28  accuracy= 0.09
# epoch= 1  step= 29  accuracy= 0.15
# epoch= 1  step= 30  accuracy= 0.08
# epoch= 1  step= 31  accuracy= 0.11
# epoch= 1  step= 32  accuracy= 0.06
# epoch= 1  step= 33  accuracy= 0.09
# epoch= 1  step= 34  accuracy= 0.17
# epoch= 1  step= 35  accuracy= 0.08
# epoch= 1  step= 36  accuracy= 0.08
# epoch= 1  step= 37  accuracy= 0.16
# epoch= 1  step= 38  accuracy= 0.12
# epoch= 1  step= 39  accuracy= 0.1
# epoch= 1  step= 40  accuracy= 0.12
# epoch= 1  step= 41  accuracy= 0.09
# epoch= 1  step= 42  accuracy= 0.13
# epoch= 1  step= 43  accuracy= 0.1
# epoch= 1  step= 44  accuracy= 0.11
# epoch= 1  step= 45  accuracy= 0.09
# epoch= 1  step= 46  accuracy= 0.07
# epoch= 1  step= 47  accuracy= 0.1
# epoch= 1  step= 48  accuracy= 0.09
# epoch= 1  step= 49  accuracy= 0.09
# epoch= 1  step= 50  accuracy= 0.09
# epoch= 1  step= 51  accuracy= 0.07
# epoch= 1  step= 52  accuracy= 0.06
# epoch= 1  step= 53  accuracy= 0.05
# epoch= 1  step= 54  accuracy= 0.1
# epoch= 1  step= 55  accuracy= 0.05
# epoch= 1  step= 56  accuracy= 0.08
# epoch= 1  step= 57  accuracy= 0.09
# epoch= 1  step= 58  accuracy= 0.07
# epoch= 1  step= 59  accuracy= 0.11
# epoch= 1  step= 60  accuracy= 0.06
# epoch= 1  step= 61  accuracy= 0.1
# epoch= 1  step= 62  accuracy= 0.13
# epoch= 1  step= 63  accuracy= 0.11
# epoch= 1  step= 64  accuracy= 0.07
# epoch= 1  step= 65  accuracy= 0.07
# epoch= 1  step= 66  accuracy= 0.08
# epoch= 1  step= 67  accuracy= 0.14
# epoch= 1  step= 68  accuracy= 0.17
# epoch= 1  step= 69  accuracy= 0.1
# epoch= 1  step= 70  accuracy= 0.1
# epoch= 1  step= 71  accuracy= 0.11
# epoch= 1  step= 72  accuracy= 0.11
# epoch= 1  step= 73  accuracy= 0.08
# epoch= 1  step= 74  accuracy= 0.11
# epoch= 1  step= 75  accuracy= 0.11
# epoch= 1  step= 76  accuracy= 0.15
# epoch= 1  step= 77  accuracy= 0.13
# epoch= 1  step= 78  accuracy= 0.15
# epoch= 1  step= 79  accuracy= 0.11
# epoch= 1  step= 80  accuracy= 0.12
# epoch= 1  step= 81  accuracy= 0.1
# epoch= 1  step= 82  accuracy= 0.07
# epoch= 1  step= 83  accuracy= 0.06
# epoch= 1  step= 84  accuracy= 0.08
# epoch= 1  step= 85  accuracy= 0.11
# epoch= 1  step= 86  accuracy= 0.14
# epoch= 1  step= 87  accuracy= 0.12
# epoch= 1  step= 88  accuracy= 0.08
# epoch= 1  step= 89  accuracy= 0.09
# epoch= 1  step= 90  accuracy= 0.07
# epoch= 1  step= 91  accuracy= 0.07
# epoch= 1  step= 92  accuracy= 0.1
# epoch= 1  step= 93  accuracy= 0.05
# epoch= 1  step= 94  accuracy= 0.06
# epoch= 1  step= 95  accuracy= 0.17
# epoch= 1  step= 96  accuracy= 0.1
# epoch= 1  step= 97  accuracy= 0.08
# epoch= 1  step= 98  accuracy= 0.07
# epoch= 1  step= 99  accuracy= 0.1
# epoch= 1  step= 100  accuracy= 0.05
# epoch= 1  step= 101  accuracy= 0.12
# epoch= 1  step= 102  accuracy= 0.11
# epoch= 1  step= 103  accuracy= 0.07
# epoch= 1  step= 104  accuracy= 0.06
# epoch= 1  step= 105  accuracy= 0.09
# epoch= 1  step= 106  accuracy= 0.06
# epoch= 1  step= 107  accuracy= 0.09
# epoch= 1  step= 108  accuracy= 0.07
# epoch= 1  step= 109  accuracy= 0.11
# epoch= 1  step= 110  accuracy= 0.07
# epoch= 1  step= 111  accuracy= 0.13
# epoch= 1  step= 112  accuracy= 0.16
# epoch= 1  step= 113  accuracy= 0.11
# epoch= 1  step= 114  accuracy= 0.05
# epoch= 1  step= 115  accuracy= 0.13
# epoch= 1  step= 116  accuracy= 0.06
# epoch= 1  step= 117  accuracy= 0.08
# epoch= 1  step= 118  accuracy= 0.09
# epoch= 1  step= 119  accuracy= 0.08
# epoch= 1  step= 120  accuracy= 0.08
# epoch= 1  step= 121  accuracy= 0.07
# epoch= 1  step= 122  accuracy= 0.16
# epoch= 1  step= 123  accuracy= 0.15
# epoch= 1  step= 124  accuracy= 0.13
# epoch= 1  step= 125  accuracy= 0.12
# epoch= 1  step= 126  accuracy= 0.1
# epoch= 1  step= 127  accuracy= 0.1
# epoch= 1  step= 128  accuracy= 0.05
# epoch= 1  step= 129  accuracy= 0.04
# epoch= 1  step= 130  accuracy= 0.11
# epoch= 1  step= 131  accuracy= 0.09
# epoch= 1  step= 132  accuracy= 0.1
# epoch= 1  step= 133  accuracy= 0.11
# epoch= 1  step= 134  accuracy= 0.12
# epoch= 1  step= 135  accuracy= 0.07
# epoch= 1  step= 136  accuracy= 0.11
# epoch= 1  step= 137  accuracy= 0.09
# epoch= 1  step= 138  accuracy= 0.09
# epoch= 1  step= 139  accuracy= 0.12
# epoch= 1  step= 140  accuracy= 0.12
# epoch= 1  step= 141  accuracy= 0.1
# epoch= 1  step= 142  accuracy= 0.08
# epoch= 1  step= 143  accuracy= 0.11
# epoch= 1  step= 144  accuracy= 0.05
# epoch= 1  step= 145  accuracy= 0.1
# epoch= 1  step= 146  accuracy= 0.1
# epoch= 1  step= 147  accuracy= 0.09
# epoch= 1  step= 148  accuracy= 0.1
# epoch= 1  step= 149  accuracy= 0.14
# epoch= 1  step= 150  accuracy= 0.03
# epoch= 1  step= 151  accuracy= 0.09
# epoch= 1  step= 152  accuracy= 0.21
# epoch= 1  step= 153  accuracy= 0.1
# epoch= 1  step= 154  accuracy= 0.14
# epoch= 1  step= 155  accuracy= 0.16
# epoch= 1  step= 156  accuracy= 0.09
# epoch= 1  step= 157  accuracy= 0.09
# epoch= 1  step= 158  accuracy= 0.08
# epoch= 1  step= 159  accuracy= 0.06
# epoch= 1  step= 160  accuracy= 0.08
# epoch= 1  step= 161  accuracy= 0.11
# epoch= 1  step= 162  accuracy= 0.11
# epoch= 1  step= 163  accuracy= 0.13
# epoch= 1  step= 164  accuracy= 0.07
# epoch= 1  step= 165  accuracy= 0.08
# epoch= 1  step= 166  accuracy= 0.05
# epoch= 1  step= 167  accuracy= 0.05
# epoch= 1  step= 168  accuracy= 0.08
# epoch= 1  step= 169  accuracy= 0.06
# epoch= 1  step= 170  accuracy= 0.06
# epoch= 1  step= 171  accuracy= 0.16
# epoch= 1  step= 172  accuracy= 0.14
# epoch= 1  step= 173  accuracy= 0.1
# epoch= 1  step= 174  accuracy= 0.16
# epoch= 1  step= 175  accuracy= 0.09
# epoch= 1  step= 176  accuracy= 0.08
# epoch= 1  step= 177  accuracy= 0.1
# epoch= 1  step= 178  accuracy= 0.11
# epoch= 1  step= 179  accuracy= 0.08
# epoch= 1  step= 180  accuracy= 0.11
# epoch= 1  step= 181  accuracy= 0.11
# epoch= 1  step= 182  accuracy= 0.16
# epoch= 1  step= 183  accuracy= 0.08
# epoch= 1  step= 184  accuracy= 0.08
# epoch= 1  step= 185  accuracy= 0.09
# epoch= 1  step= 186  accuracy= 0.1
# epoch= 1  step= 187  accuracy= 0.1
# epoch= 1  step= 188  accuracy= 0.07
# epoch= 1  step= 189  accuracy= 0.12
# epoch= 1  step= 190  accuracy= 0.1
# epoch= 1  step= 191  accuracy= 0.1
# epoch= 1  step= 192  accuracy= 0.11
# epoch= 1  step= 193  accuracy= 0.08
# epoch= 1  step= 194  accuracy= 0.06
# epoch= 1  step= 195  accuracy= 0.1
# epoch= 1  step= 196  accuracy= 0.07
# epoch= 1  step= 197  accuracy= 0.07
# epoch= 1  step= 198  accuracy= 0.1
# epoch= 1  step= 199  accuracy= 0.06
# epoch= 1  step= 200  accuracy= 0.04
# epoch= 1  step= 201  accuracy= 0.08
# epoch= 1  step= 202  accuracy= 0.09
# epoch= 1  step= 203  accuracy= 0.15
# epoch= 1  step= 204  accuracy= 0.08
# epoch= 1  step= 205  accuracy= 0.05
# epoch= 1  step= 206  accuracy= 0.09
# epoch= 1  step= 207  accuracy= 0.07
# epoch= 1  step= 208  accuracy= 0.12
# epoch= 1  step= 209  accuracy= 0.07
# epoch= 1  step= 210  accuracy= 0.09
# epoch= 1  step= 211  accuracy= 0.12
# epoch= 1  step= 212  accuracy= 0.08
# epoch= 1  step= 213  accuracy= 0.12
# epoch= 1  step= 214  accuracy= 0.1
# epoch= 1  step= 215  accuracy= 0.07
# epoch= 1  step= 216  accuracy= 0.04
# epoch= 1  step= 217  accuracy= 0.15
# epoch= 1  step= 218  accuracy= 0.12
# epoch= 1  step= 219  accuracy= 0.1
# epoch= 1  step= 220  accuracy= 0.06
# epoch= 1  step= 221  accuracy= 0.08
# epoch= 1  step= 222  accuracy= 0.04
# epoch= 1  step= 223  accuracy= 0.07
# epoch= 1  step= 224  accuracy= 0.14
# epoch= 1  step= 225  accuracy= 0.13
# epoch= 1  step= 226  accuracy= 0.1
# epoch= 1  step= 227  accuracy= 0.03
# epoch= 1  step= 228  accuracy= 0.1
# epoch= 1  step= 229  accuracy= 0.06
# epoch= 1  step= 230  accuracy= 0.1
# epoch= 1  step= 231  accuracy= 0.1
# epoch= 1  step= 232  accuracy= 0.14
# epoch= 1  step= 233  accuracy= 0.08
# epoch= 1  step= 234  accuracy= 0.07
# epoch= 1  step= 235  accuracy= 0.09
# epoch= 1  step= 236  accuracy= 0.05
# epoch= 1  step= 237  accuracy= 0.08
# epoch= 1  step= 238  accuracy= 0.12
# epoch= 1  step= 239  accuracy= 0.12
# epoch= 1  step= 240  accuracy= 0.1
# epoch= 1  step= 241  accuracy= 0.09
# epoch= 1  step= 242  accuracy= 0.1
# epoch= 1  step= 243  accuracy= 0.12
# epoch= 1  step= 244  accuracy= 0.13
# epoch= 1  step= 245  accuracy= 0.11
# epoch= 1  step= 246  accuracy= 0.15
# epoch= 1  step= 247  accuracy= 0.08
# epoch= 1  step= 248  accuracy= 0.13
# epoch= 1  step= 249  accuracy= 0.11
# epoch= 1  step= 250  accuracy= 0.08
# epoch= 1  step= 251  accuracy= 0.13
# epoch= 1  step= 252  accuracy= 0.09
# epoch= 1  step= 253  accuracy= 0.16
# epoch= 1  step= 254  accuracy= 0.11
# epoch= 1  step= 255  accuracy= 0.08
# epoch= 1  step= 256  accuracy= 0.04
# epoch= 1  step= 257  accuracy= 0.15
# epoch= 1  step= 258  accuracy= 0.11
# epoch= 1  step= 259  accuracy= 0.08
# epoch= 1  step= 260  accuracy= 0.07
# epoch= 1  step= 261  accuracy= 0.09
# epoch= 1  step= 262  accuracy= 0.12
# epoch= 1  step= 263  accuracy= 0.03
# epoch= 1  step= 264  accuracy= 0.15
# epoch= 1  step= 265  accuracy= 0.13
# epoch= 1  step= 266  accuracy= 0.04
# epoch= 1  step= 267  accuracy= 0.04
# epoch= 1  step= 268  accuracy= 0.01
# epoch= 1  step= 269  accuracy= 0.1
# epoch= 1  step= 270  accuracy= 0.11
# epoch= 1  step= 271  accuracy= 0.11
# epoch= 1  step= 272  accuracy= 0.06
# epoch= 1  step= 273  accuracy= 0.02
# epoch= 1  step= 274  accuracy= 0.04
# epoch= 1  step= 275  accuracy= 0.06
# epoch= 1  step= 276  accuracy= 0.1
# epoch= 1  step= 277  accuracy= 0.13
# epoch= 1  step= 278  accuracy= 0.13
# epoch= 1  step= 279  accuracy= 0.08
# epoch= 1  step= 280  accuracy= 0.05
# epoch= 1  step= 281  accuracy= 0.13
# epoch= 1  step= 282  accuracy= 0.09
# epoch= 1  step= 283  accuracy= 0.05
# epoch= 1  step= 284  accuracy= 0.09
# epoch= 1  step= 285  accuracy= 0.05
# epoch= 1  step= 286  accuracy= 0.1
# epoch= 1  step= 287  accuracy= 0.07
# epoch= 1  step= 288  accuracy= 0.09
# epoch= 1  step= 289  accuracy= 0.1
# epoch= 1  step= 290  accuracy= 0.1
# epoch= 1  step= 291  accuracy= 0.1
# epoch= 1  step= 292  accuracy= 0.17
# epoch= 1  step= 293  accuracy= 0.08
# epoch= 1  step= 294  accuracy= 0.13
# epoch= 1  step= 295  accuracy= 0.08
# epoch= 1  step= 296  accuracy= 0.13
# epoch= 1  step= 297  accuracy= 0.09
# epoch= 1  step= 298  accuracy= 0.09
# epoch= 1  step= 299  accuracy= 0.09
# epoch= 1  step= 300  accuracy= 0.1
# epoch= 1  step= 301  accuracy= 0.09
# epoch= 1  step= 302  accuracy= 0.04
# epoch= 1  step= 303  accuracy= 0.06
# epoch= 1  step= 304  accuracy= 0.12
# epoch= 1  step= 305  accuracy= 0.14
# epoch= 1  step= 306  accuracy= 0.06
# epoch= 1  step= 307  accuracy= 0.1
# epoch= 1  step= 308  accuracy= 0.05
# epoch= 1  step= 309  accuracy= 0.09
# epoch= 1  step= 310  accuracy= 0.07
# epoch= 1  step= 311  accuracy= 0.07
# epoch= 1  step= 312  accuracy= 0.14
# epoch= 1  step= 313  accuracy= 0.11
# epoch= 1  step= 314  accuracy= 0.09
# epoch= 1  step= 315  accuracy= 0.15
# epoch= 1  step= 316  accuracy= 0.06
# epoch= 1  step= 317  accuracy= 0.09
# epoch= 1  step= 318  accuracy= 0.07
# epoch= 1  step= 319  accuracy= 0.07
# epoch= 1  step= 320  accuracy= 0.07
# epoch= 1  step= 321  accuracy= 0.16
# epoch= 1  step= 322  accuracy= 0.06
# epoch= 1  step= 323  accuracy= 0.12
# epoch= 1  step= 324  accuracy= 0.11
# epoch= 1  step= 325  accuracy= 0.07
# epoch= 1  step= 326  accuracy= 0.05
# epoch= 1  step= 327  accuracy= 0.08
# epoch= 1  step= 328  accuracy= 0.11
# epoch= 1  step= 329  accuracy= 0.06
# epoch= 1  step= 330  accuracy= 0.11
# epoch= 1  step= 331  accuracy= 0.04
# epoch= 1  step= 332  accuracy= 0.05
# epoch= 1  step= 333  accuracy= 0.1
# epoch= 1  step= 334  accuracy= 0.11
# epoch= 1  step= 335  accuracy= 0.07
# epoch= 1  step= 336  accuracy= 0.06
# epoch= 1  step= 337  accuracy= 0.08
# epoch= 1  step= 338  accuracy= 0.1
# epoch= 1  step= 339  accuracy= 0.08
# epoch= 1  step= 340  accuracy= 0.09
# epoch= 1  step= 341  accuracy= 0.09
# epoch= 1  step= 342  accuracy= 0.05
# epoch= 1  step= 343  accuracy= 0.06
# epoch= 1  step= 344  accuracy= 0.06
# epoch= 1  step= 345  accuracy= 0.12
# epoch= 1  step= 346  accuracy= 0.13
# epoch= 1  step= 347  accuracy= 0.12
# epoch= 1  step= 348  accuracy= 0.07
# epoch= 1  step= 349  accuracy= 0.11
# epoch= 1  step= 350  accuracy= 0.08
# epoch= 1  step= 351  accuracy= 0.07
# epoch= 1  step= 352  accuracy= 0.11
# epoch= 1  step= 353  accuracy= 0.17
# epoch= 1  step= 354  accuracy= 0.09
# epoch= 1  step= 355  accuracy= 0.1
# epoch= 1  step= 356  accuracy= 0.12
# epoch= 1  step= 357  accuracy= 0.08
# epoch= 1  step= 358  accuracy= 0.03
# epoch= 1  step= 359  accuracy= 0.15
# epoch= 1  step= 360  accuracy= 0.15
# epoch= 1  step= 361  accuracy= 0.11
# epoch= 1  step= 362  accuracy= 0.08
# epoch= 1  step= 363  accuracy= 0.09
# epoch= 1  step= 364  accuracy= 0.13
# epoch= 1  step= 365  accuracy= 0.06
# epoch= 1  step= 366  accuracy= 0.13
# epoch= 1  step= 367  accuracy= 0.09
# epoch= 1  step= 368  accuracy= 0.09
# epoch= 1  step= 369  accuracy= 0.09
# epoch= 1  step= 370  accuracy= 0.06
# epoch= 1  step= 371  accuracy= 0.1
# epoch= 1  step= 372  accuracy= 0.04
# epoch= 1  step= 373  accuracy= 0.07
# epoch= 1  step= 374  accuracy= 0.07
# epoch= 1  step= 375  accuracy= 0.01
# epoch= 1  step= 376  accuracy= 0.07
# epoch= 1  step= 377  accuracy= 0.08
# epoch= 1  step= 378  accuracy= 0.11
# epoch= 1  step= 379  accuracy= 0.07
# epoch= 1  step= 380  accuracy= 0.05
# epoch= 1  step= 381  accuracy= 0.08
# epoch= 1  step= 382  accuracy= 0.12
# epoch= 1  step= 383  accuracy= 0.06
# epoch= 1  step= 384  accuracy= 0.13
# epoch= 1  step= 385  accuracy= 0.14
# epoch= 1  step= 386  accuracy= 0.12
# epoch= 1  step= 387  accuracy= 0.12
# epoch= 1  step= 388  accuracy= 0.09
# epoch= 1  step= 389  accuracy= 0.11
# epoch= 1  step= 390  accuracy= 0.11
# epoch= 1  step= 391  accuracy= 0.08
# epoch= 1  step= 392  accuracy= 0.07
# epoch= 1  step= 393  accuracy= 0.1
# epoch= 1  step= 394  accuracy= 0.06
# epoch= 1  step= 395  accuracy= 0.04
# epoch= 1  step= 396  accuracy= 0.06
# epoch= 1  step= 397  accuracy= 0.11
# epoch= 1  step= 398  accuracy= 0.1
# epoch= 1  step= 399  accuracy= 0.12
# epoch= 1  step= 400  accuracy= 0.12
# epoch= 1  step= 401  accuracy= 0.07
# epoch= 1  step= 402  accuracy= 0.08
# epoch= 1  step= 403  accuracy= 0.15
# epoch= 1  step= 404  accuracy= 0.09
# epoch= 1  step= 405  accuracy= 0.14
# epoch= 1  step= 406  accuracy= 0.11
# epoch= 1  step= 407  accuracy= 0.09
# epoch= 1  step= 408  accuracy= 0.06
# epoch= 1  step= 409  accuracy= 0.04
# epoch= 1  step= 410  accuracy= 0.05
# epoch= 1  step= 411  accuracy= 0.1
# epoch= 1  step= 412  accuracy= 0.09
# epoch= 1  step= 413  accuracy= 0.1
# epoch= 1  step= 414  accuracy= 0.1
# epoch= 1  step= 415  accuracy= 0.11
# epoch= 1  step= 416  accuracy= 0.06
# epoch= 1  step= 417  accuracy= 0.09
# epoch= 1  step= 418  accuracy= 0.09
# epoch= 1  step= 419  accuracy= 0.07
# epoch= 1  step= 420  accuracy= 0.1
# epoch= 1  step= 421  accuracy= 0.12
# epoch= 1  step= 422  accuracy= 0.13
# epoch= 1  step= 423  accuracy= 0.07
# epoch= 1  step= 424  accuracy= 0.09
# epoch= 1  step= 425  accuracy= 0.11
# epoch= 1  step= 426  accuracy= 0.12
# epoch= 1  step= 427  accuracy= 0.13
# epoch= 1  step= 428  accuracy= 0.14
# epoch= 1  step= 429  accuracy= 0.11
# epoch= 1  step= 430  accuracy= 0.18
# epoch= 1  step= 431  accuracy= 0.07
# epoch= 1  step= 432  accuracy= 0.12
# epoch= 1  step= 433  accuracy= 0.11
# epoch= 1  step= 434  accuracy= 0.07
# epoch= 1  step= 435  accuracy= 0.1
# epoch= 1  step= 436  accuracy= 0.05
# epoch= 1  step= 437  accuracy= 0.14
# epoch= 1  step= 438  accuracy= 0.12
# epoch= 1  step= 439  accuracy= 0.12
# epoch= 1  step= 440  accuracy= 0.07
# epoch= 1  step= 441  accuracy= 0.11
# epoch= 1  step= 442  accuracy= 0.11
# epoch= 1  step= 443  accuracy= 0.05
# epoch= 1  step= 444  accuracy= 0.1
# epoch= 1  step= 445  accuracy= 0.08
# epoch= 1  step= 446  accuracy= 0.08
# epoch= 1  step= 447  accuracy= 0.04
# epoch= 1  step= 448  accuracy= 0.1
# epoch= 1  step= 449  accuracy= 0.12
# epoch= 1  step= 450  accuracy= 0.13
# epoch= 1  step= 451  accuracy= 0.08
# epoch= 1  step= 452  accuracy= 0.02
# epoch= 1  step= 453  accuracy= 0.06
# epoch= 1  step= 454  accuracy= 0.08
# epoch= 1  step= 455  accuracy= 0.08
# epoch= 1  step= 456  accuracy= 0.03
# epoch= 1  step= 457  accuracy= 0.06
# epoch= 1  step= 458  accuracy= 0.1
# epoch= 1  step= 459  accuracy= 0.1
# epoch= 1  step= 460  accuracy= 0.11
# epoch= 1  step= 461  accuracy= 0.12
# epoch= 1  step= 462  accuracy= 0.06
# epoch= 1  step= 463  accuracy= 0.08
# epoch= 1  step= 464  accuracy= 0.06
# epoch= 1  step= 465  accuracy= 0.08
# epoch= 1  step= 466  accuracy= 0.09
# epoch= 1  step= 467  accuracy= 0.07
# epoch= 1  step= 468  accuracy= 0.09
# epoch= 1  step= 469  accuracy= 0.11
# epoch= 1  step= 470  accuracy= 0.14
# epoch= 1  step= 471  accuracy= 0.12
# epoch= 1  step= 472  accuracy= 0.13
# epoch= 1  step= 473  accuracy= 0.1
# epoch= 1  step= 474  accuracy= 0.09
# epoch= 1  step= 475  accuracy= 0.11
# epoch= 1  step= 476  accuracy= 0.11
# epoch= 1  step= 477  accuracy= 0.06
# epoch= 1  step= 478  accuracy= 0.07
# epoch= 1  step= 479  accuracy= 0.1
# epoch= 1  step= 480  accuracy= 0.09
# epoch= 1  step= 481  accuracy= 0.07
# epoch= 1  step= 482  accuracy= 0.06
# epoch= 1  step= 483  accuracy= 0.12
# epoch= 1  step= 484  accuracy= 0.1
# epoch= 1  step= 485  accuracy= 0.11
# epoch= 1  step= 486  accuracy= 0.11
# epoch= 1  step= 487  accuracy= 0.13
# epoch= 1  step= 488  accuracy= 0.07
# epoch= 1  step= 489  accuracy= 0.12
# epoch= 1  step= 490  accuracy= 0.05
# epoch= 1  step= 491  accuracy= 0.12
# epoch= 1  step= 492  accuracy= 0.08
# epoch= 1  step= 493  accuracy= 0.11
# epoch= 1  step= 494  accuracy= 0.06
# epoch= 1  step= 495  accuracy= 0.13
# epoch= 1  step= 496  accuracy= 0.07
# epoch= 1  step= 497  accuracy= 0.06
# epoch= 1  step= 498  accuracy= 0.03
# epoch= 1  step= 499  accuracy= 0.05
# epoch= 1  step= 500  accuracy= 0.06
# epoch= 1  step= 501  accuracy= 0.1
# epoch= 1  step= 502  accuracy= 0.09
# epoch= 1  step= 503  accuracy= 0.08
# epoch= 1  step= 504  accuracy= 0.11
# epoch= 1  step= 505  accuracy= 0.06
# epoch= 1  step= 506  accuracy= 0.07
# epoch= 1  step= 507  accuracy= 0.17
# epoch= 1  step= 508  accuracy= 0.09
# epoch= 1  step= 509  accuracy= 0.11
# epoch= 1  step= 510  accuracy= 0.09
# epoch= 1  step= 511  accuracy= 0.06
# epoch= 1  step= 512  accuracy= 0.07
# epoch= 1  step= 513  accuracy= 0.04
# epoch= 1  step= 514  accuracy= 0.04
# epoch= 1  step= 515  accuracy= 0.04
# epoch= 1  step= 516  accuracy= 0.04
# epoch= 1  step= 517  accuracy= 0.09
# epoch= 1  step= 518  accuracy= 0.14
# epoch= 1  step= 519  accuracy= 0.12
# epoch= 1  step= 520  accuracy= 0.11
# epoch= 1  step= 521  accuracy= 0.07
# epoch= 1  step= 522  accuracy= 0.1
# epoch= 1  step= 523  accuracy= 0.13
# epoch= 1  step= 524  accuracy= 0.08
# epoch= 1  step= 525  accuracy= 0.06
# epoch= 1  step= 526  accuracy= 0.13
# epoch= 1  step= 527  accuracy= 0.1
# epoch= 1  step= 528  accuracy= 0.14
# epoch= 1  step= 529  accuracy= 0.05
# epoch= 1  step= 530  accuracy= 0.1
# epoch= 1  step= 531  accuracy= 0.16
# epoch= 1  step= 532  accuracy= 0.07
# epoch= 1  step= 533  accuracy= 0.12
# epoch= 1  step= 534  accuracy= 0.08
# epoch= 1  step= 535  accuracy= 0.09
# epoch= 1  step= 536  accuracy= 0.09
# epoch= 1  step= 537  accuracy= 0.11
# epoch= 1  step= 538  accuracy= 0.11
# epoch= 1  step= 539  accuracy= 0.09
# epoch= 1  step= 540  accuracy= 0.13
# epoch= 1  step= 541  accuracy= 0.09
# epoch= 1  step= 542  accuracy= 0.06
# epoch= 1  step= 543  accuracy= 0.06
# epoch= 1  step= 544  accuracy= 0.04
# epoch= 1  step= 545  accuracy= 0.11
# epoch= 1  step= 546  accuracy= 0.12
# epoch= 1  step= 547  accuracy= 0.1
# epoch= 1  step= 548  accuracy= 0.08
# epoch= 1  step= 549  accuracy= 0.09
# epoch= 1  step= 550  accuracy= 0.08
# epoch= 1  step= 551  accuracy= 0.09
# epoch= 1  step= 552  accuracy= 0.1
# epoch= 1  step= 553  accuracy= 0.09
# epoch= 1  step= 554  accuracy= 0.11
# epoch= 1  step= 555  accuracy= 0.08
# epoch= 1  step= 556  accuracy= 0.12
# epoch= 1  step= 557  accuracy= 0.11
# epoch= 1  step= 558  accuracy= 0.11
# epoch= 1  step= 559  accuracy= 0.05
# epoch= 1  step= 560  accuracy= 0.15
# epoch= 1  step= 561  accuracy= 0.06
# epoch= 1  step= 562  accuracy= 0.06
# epoch= 1  step= 563  accuracy= 0.03
# epoch= 1  step= 564  accuracy= 0.09
# epoch= 1  step= 565  accuracy= 0.06
# epoch= 1  step= 566  accuracy= 0.03
# epoch= 1  step= 567  accuracy= 0.06
# epoch= 1  step= 568  accuracy= 0.09
# epoch= 1  step= 569  accuracy= 0.06
# epoch= 1  step= 570  accuracy= 0.07
# epoch= 1  step= 571  accuracy= 0.1
# epoch= 1  step= 572  accuracy= 0.13
# epoch= 1  step= 573  accuracy= 0.18
# epoch= 1  step= 574  accuracy= 0.12
# epoch= 1  step= 575  accuracy= 0.08
# epoch= 1  step= 576  accuracy= 0.18
# epoch= 1  step= 577  accuracy= 0.08
# epoch= 1  step= 578  accuracy= 0.05
# epoch= 1  step= 579  accuracy= 0.09
# epoch= 1  step= 580  accuracy= 0.11
# epoch= 1  step= 581  accuracy= 0.1
# epoch= 1  step= 582  accuracy= 0.07
# epoch= 1  step= 583  accuracy= 0.08
# epoch= 1  step= 584  accuracy= 0.1
# epoch= 1  step= 585  accuracy= 0.09
# epoch= 1  step= 586  accuracy= 0.15
# epoch= 1  step= 587  accuracy= 0.16
# epoch= 1  step= 588  accuracy= 0.09
# epoch= 1  step= 589  accuracy= 0.09
# epoch= 1  step= 590  accuracy= 0.12
# epoch= 1  step= 591  accuracy= 0.14
# epoch= 1  step= 592  accuracy= 0.12
# epoch= 1  step= 593  accuracy= 0.11
# epoch= 1  step= 594  accuracy= 0.11
# epoch= 1  step= 595  accuracy= 0.09
# epoch= 1  step= 596  accuracy= 0.09
# epoch= 1  step= 597  accuracy= 0.1
# epoch= 1  step= 598  accuracy= 0.07
# epoch= 1  step= 599  accuracy= 0.07
# epoch= 2  step= 0  accuracy= 0.1
# epoch= 2  step= 1  accuracy= 0.06
# epoch= 2  step= 2  accuracy= 0.07
# epoch= 2  step= 3  accuracy= 0.09
# epoch= 2  step= 4  accuracy= 0.13
# epoch= 2  step= 5  accuracy= 0.1
# epoch= 2  step= 6  accuracy= 0.07
# epoch= 2  step= 7  accuracy= 0.08
# epoch= 2  step= 8  accuracy= 0.14
# epoch= 2  step= 9  accuracy= 0.15
# epoch= 2  step= 10  accuracy= 0.14
# epoch= 2  step= 11  accuracy= 0.09
# epoch= 2  step= 12  accuracy= 0.11
# epoch= 2  step= 13  accuracy= 0.06
# epoch= 2  step= 14  accuracy= 0.09
# epoch= 2  step= 15  accuracy= 0.07
# epoch= 2  step= 16  accuracy= 0.11
# epoch= 2  step= 17  accuracy= 0.1
# epoch= 2  step= 18  accuracy= 0.09
# epoch= 2  step= 19  accuracy= 0.03
# epoch= 2  step= 20  accuracy= 0.08
# epoch= 2  step= 21  accuracy= 0.08
# epoch= 2  step= 22  accuracy= 0.07
# epoch= 2  step= 23  accuracy= 0.15
# epoch= 2  step= 24  accuracy= 0.16
# epoch= 2  step= 25  accuracy= 0.13
# epoch= 2  step= 26  accuracy= 0.09
# epoch= 2  step= 27  accuracy= 0.08
# epoch= 2  step= 28  accuracy= 0.12
# epoch= 2  step= 29  accuracy= 0.12
# epoch= 2  step= 30  accuracy= 0.08
# epoch= 2  step= 31  accuracy= 0.11
# epoch= 2  step= 32  accuracy= 0.07
# epoch= 2  step= 33  accuracy= 0.07
# epoch= 2  step= 34  accuracy= 0.16
# epoch= 2  step= 35  accuracy= 0.09
# epoch= 2  step= 36  accuracy= 0.07
# epoch= 2  step= 37  accuracy= 0.16
# epoch= 2  step= 38  accuracy= 0.13
# epoch= 2  step= 39  accuracy= 0.1
# epoch= 2  step= 40  accuracy= 0.11
# epoch= 2  step= 41  accuracy= 0.1
# epoch= 2  step= 42  accuracy= 0.13
# epoch= 2  step= 43  accuracy= 0.11
# epoch= 2  step= 44  accuracy= 0.09
# epoch= 2  step= 45  accuracy= 0.08
# epoch= 2  step= 46  accuracy= 0.05
# epoch= 2  step= 47  accuracy= 0.08
# epoch= 2  step= 48  accuracy= 0.08
# epoch= 2  step= 49  accuracy= 0.12
# epoch= 2  step= 50  accuracy= 0.08
# epoch= 2  step= 51  accuracy= 0.1
# epoch= 2  step= 52  accuracy= 0.1
# epoch= 2  step= 53  accuracy= 0.06
# epoch= 2  step= 54  accuracy= 0.1
# epoch= 2  step= 55  accuracy= 0.05
# epoch= 2  step= 56  accuracy= 0.11
# epoch= 2  step= 57  accuracy= 0.09
# epoch= 2  step= 58  accuracy= 0.06
# epoch= 2  step= 59  accuracy= 0.12
# epoch= 2  step= 60  accuracy= 0.09
# epoch= 2  step= 61  accuracy= 0.07
# epoch= 2  step= 62  accuracy= 0.12
# epoch= 2  step= 63  accuracy= 0.09
# epoch= 2  step= 64  accuracy= 0.08
# epoch= 2  step= 65  accuracy= 0.06
# epoch= 2  step= 66  accuracy= 0.04
# epoch= 2  step= 67  accuracy= 0.12
# epoch= 2  step= 68  accuracy= 0.16
# epoch= 2  step= 69  accuracy= 0.1
# epoch= 2  step= 70  accuracy= 0.13
# epoch= 2  step= 71  accuracy= 0.11
# epoch= 2  step= 72  accuracy= 0.11
# epoch= 2  step= 73  accuracy= 0.07
# epoch= 2  step= 74  accuracy= 0.1
# epoch= 2  step= 75  accuracy= 0.1
# epoch= 2  step= 76  accuracy= 0.15
# epoch= 2  step= 77  accuracy= 0.13
# epoch= 2  step= 78  accuracy= 0.16
# epoch= 2  step= 79  accuracy= 0.12
# epoch= 2  step= 80  accuracy= 0.12
# epoch= 2  step= 81  accuracy= 0.11
# epoch= 2  step= 82  accuracy= 0.05
# epoch= 2  step= 83  accuracy= 0.06
# epoch= 2  step= 84  accuracy= 0.09
# epoch= 2  step= 85  accuracy= 0.09
# epoch= 2  step= 86  accuracy= 0.12
# epoch= 2  step= 87  accuracy= 0.11
# epoch= 2  step= 88  accuracy= 0.08
# epoch= 2  step= 89  accuracy= 0.08
# epoch= 2  step= 90  accuracy= 0.06
# epoch= 2  step= 91  accuracy= 0.08
# epoch= 2  step= 92  accuracy= 0.08
# epoch= 2  step= 93  accuracy= 0.05
# epoch= 2  step= 94  accuracy= 0.07
# epoch= 2  step= 95  accuracy= 0.17
# epoch= 2  step= 96  accuracy= 0.1
# epoch= 2  step= 97  accuracy= 0.07
# epoch= 2  step= 98  accuracy= 0.09
# epoch= 2  step= 99  accuracy= 0.11
# epoch= 2  step= 100  accuracy= 0.04
# epoch= 2  step= 101  accuracy= 0.13
# epoch= 2  step= 102  accuracy= 0.1
# epoch= 2  step= 103  accuracy= 0.07
# epoch= 2  step= 104  accuracy= 0.06
# epoch= 2  step= 105  accuracy= 0.1
# epoch= 2  step= 106  accuracy= 0.06
# epoch= 2  step= 107  accuracy= 0.09
# epoch= 2  step= 108  accuracy= 0.07
# epoch= 2  step= 109  accuracy= 0.11
# epoch= 2  step= 110  accuracy= 0.08
# epoch= 2  step= 111  accuracy= 0.13
# epoch= 2  step= 112  accuracy= 0.16
# epoch= 2  step= 113  accuracy= 0.12
# epoch= 2  step= 114  accuracy= 0.07
# epoch= 2  step= 115  accuracy= 0.13
# epoch= 2  step= 116  accuracy= 0.06
# epoch= 2  step= 117  accuracy= 0.08
# epoch= 2  step= 118  accuracy= 0.09
# epoch= 2  step= 119  accuracy= 0.1
# epoch= 2  step= 120  accuracy= 0.09
# epoch= 2  step= 121  accuracy= 0.07
# epoch= 2  step= 122  accuracy= 0.18
# epoch= 2  step= 123  accuracy= 0.15
# epoch= 2  step= 124  accuracy= 0.12
# epoch= 2  step= 125  accuracy= 0.12
# epoch= 2  step= 126  accuracy= 0.09
# epoch= 2  step= 127  accuracy= 0.1
# epoch= 2  step= 128  accuracy= 0.05
# epoch= 2  step= 129  accuracy= 0.05
# epoch= 2  step= 130  accuracy= 0.13
# epoch= 2  step= 131  accuracy= 0.09
# epoch= 2  step= 132  accuracy= 0.1
# epoch= 2  step= 133  accuracy= 0.11
# epoch= 2  step= 134  accuracy= 0.12
# epoch= 2  step= 135  accuracy= 0.07
# epoch= 2  step= 136  accuracy= 0.11
# epoch= 2  step= 137  accuracy= 0.08
# epoch= 2  step= 138  accuracy= 0.08
# epoch= 2  step= 139  accuracy= 0.12
# epoch= 2  step= 140  accuracy= 0.12
# epoch= 2  step= 141  accuracy= 0.1
# epoch= 2  step= 142  accuracy= 0.07
# epoch= 2  step= 143  accuracy= 0.11
# epoch= 2  step= 144  accuracy= 0.05
# epoch= 2  step= 145  accuracy= 0.1
# epoch= 2  step= 146  accuracy= 0.1
# epoch= 2  step= 147  accuracy= 0.08
# epoch= 2  step= 148  accuracy= 0.09
# epoch= 2  step= 149  accuracy= 0.14
# epoch= 2  step= 150  accuracy= 0.05
# epoch= 2  step= 151  accuracy= 0.09
# epoch= 2  step= 152  accuracy= 0.21
# epoch= 2  step= 153  accuracy= 0.1
# epoch= 2  step= 154  accuracy= 0.14
# epoch= 2  step= 155  accuracy= 0.15
# epoch= 2  step= 156  accuracy= 0.08
# epoch= 2  step= 157  accuracy= 0.12
# epoch= 2  step= 158  accuracy= 0.08
# epoch= 2  step= 159  accuracy= 0.07
# epoch= 2  step= 160  accuracy= 0.08
# epoch= 2  step= 161  accuracy= 0.11
# epoch= 2  step= 162  accuracy= 0.11
# epoch= 2  step= 163  accuracy= 0.13
# epoch= 2  step= 164  accuracy= 0.07
# epoch= 2  step= 165  accuracy= 0.08
# epoch= 2  step= 166  accuracy= 0.05
# epoch= 2  step= 167  accuracy= 0.05
# epoch= 2  step= 168  accuracy= 0.09
# epoch= 2  step= 169  accuracy= 0.07
# epoch= 2  step= 170  accuracy= 0.05
# epoch= 2  step= 171  accuracy= 0.16
# epoch= 2  step= 172  accuracy= 0.14
# epoch= 2  step= 173  accuracy= 0.1
# epoch= 2  step= 174  accuracy= 0.16
# epoch= 2  step= 175  accuracy= 0.09
# epoch= 2  step= 176  accuracy= 0.08
# epoch= 2  step= 177  accuracy= 0.11
# epoch= 2  step= 178  accuracy= 0.1
# epoch= 2  step= 179  accuracy= 0.1
# epoch= 2  step= 180  accuracy= 0.11
# epoch= 2  step= 181  accuracy= 0.11
# epoch= 2  step= 182  accuracy= 0.13
# epoch= 2  step= 183  accuracy= 0.1
# epoch= 2  step= 184  accuracy= 0.09
# epoch= 2  step= 185  accuracy= 0.1
# epoch= 2  step= 186  accuracy= 0.1
# epoch= 2  step= 187  accuracy= 0.12
# epoch= 2  step= 188  accuracy= 0.06
# epoch= 2  step= 189  accuracy= 0.12
# epoch= 2  step= 190  accuracy= 0.09
# epoch= 2  step= 191  accuracy= 0.1
# epoch= 2  step= 192  accuracy= 0.12
# epoch= 2  step= 193  accuracy= 0.09
# epoch= 2  step= 194  accuracy= 0.06
# epoch= 2  step= 195  accuracy= 0.12
# epoch= 2  step= 196  accuracy= 0.07
# epoch= 2  step= 197  accuracy= 0.06
# epoch= 2  step= 198  accuracy= 0.1
# epoch= 2  step= 199  accuracy= 0.08
# epoch= 2  step= 200  accuracy= 0.06
# epoch= 2  step= 201  accuracy= 0.05
# epoch= 2  step= 202  accuracy= 0.08
# epoch= 2  step= 203  accuracy= 0.16
# epoch= 2  step= 204  accuracy= 0.08
# epoch= 2  step= 205  accuracy= 0.07
# epoch= 2  step= 206  accuracy= 0.07
# epoch= 2  step= 207  accuracy= 0.07
# epoch= 2  step= 208  accuracy= 0.13
# epoch= 2  step= 209  accuracy= 0.07
# epoch= 2  step= 210  accuracy= 0.09
# epoch= 2  step= 211  accuracy= 0.18
# epoch= 2  step= 212  accuracy= 0.12
# epoch= 2  step= 213  accuracy= 0.15
# epoch= 2  step= 214  accuracy= 0.12
# epoch= 2  step= 215  accuracy= 0.08
# epoch= 2  step= 216  accuracy= 0.07
# epoch= 2  step= 217  accuracy= 0.19
# epoch= 2  step= 218  accuracy= 0.18
# epoch= 2  step= 219  accuracy= 0.12
# epoch= 2  step= 220  accuracy= 0.09
# epoch= 2  step= 221  accuracy= 0.15
# epoch= 2  step= 222  accuracy= 0.06
# epoch= 2  step= 223  accuracy= 0.07
# epoch= 2  step= 224  accuracy= 0.15
# epoch= 2  step= 225  accuracy= 0.12
# epoch= 2  step= 226  accuracy= 0.08
# epoch= 2  step= 227  accuracy= 0.07
# epoch= 2  step= 228  accuracy= 0.13
# epoch= 2  step= 229  accuracy= 0.11
# epoch= 2  step= 230  accuracy= 0.15
# epoch= 2  step= 231  accuracy= 0.13
# epoch= 2  step= 232  accuracy= 0.15
# epoch= 2  step= 233  accuracy= 0.11
# epoch= 2  step= 234  accuracy= 0.18
# epoch= 2  step= 235  accuracy= 0.14
# epoch= 2  step= 236  accuracy= 0.07
# epoch= 2  step= 237  accuracy= 0.1
# epoch= 2  step= 238  accuracy= 0.13
# epoch= 2  step= 239  accuracy= 0.11
# epoch= 2  step= 240  accuracy= 0.15
# epoch= 2  step= 241  accuracy= 0.1
# epoch= 2  step= 242  accuracy= 0.1
# epoch= 2  step= 243  accuracy= 0.16
# epoch= 2  step= 244  accuracy= 0.15
# epoch= 2  step= 245  accuracy= 0.14
# epoch= 2  step= 246  accuracy= 0.14
# epoch= 2  step= 247  accuracy= 0.12
# epoch= 2  step= 248  accuracy= 0.15
# epoch= 2  step= 249  accuracy= 0.12
# epoch= 2  step= 250  accuracy= 0.13
# epoch= 2  step= 251  accuracy= 0.16
# epoch= 2  step= 252  accuracy= 0.13
# epoch= 2  step= 253  accuracy= 0.18
# epoch= 2  step= 254  accuracy= 0.16
# epoch= 2  step= 255  accuracy= 0.14
# epoch= 2  step= 256  accuracy= 0.07
# epoch= 2  step= 257  accuracy= 0.2
# epoch= 2  step= 258  accuracy= 0.15
# epoch= 2  step= 259  accuracy= 0.12
# epoch= 2  step= 260  accuracy= 0.13
# epoch= 2  step= 261  accuracy= 0.12
# epoch= 2  step= 262  accuracy= 0.13
# epoch= 2  step= 263  accuracy= 0.08
# epoch= 2  step= 264  accuracy= 0.12
# epoch= 2  step= 265  accuracy= 0.18
# epoch= 2  step= 266  accuracy= 0.09
# epoch= 2  step= 267  accuracy= 0.14
# epoch= 2  step= 268  accuracy= 0.07
# epoch= 2  step= 269  accuracy= 0.16
# epoch= 2  step= 270  accuracy= 0.17
# epoch= 2  step= 271  accuracy= 0.16
# epoch= 2  step= 272  accuracy= 0.11
# epoch= 2  step= 273  accuracy= 0.09
# epoch= 2  step= 274  accuracy= 0.1
# epoch= 2  step= 275  accuracy= 0.11
# epoch= 2  step= 276  accuracy= 0.1
# epoch= 2  step= 277  accuracy= 0.11
# epoch= 2  step= 278  accuracy= 0.14
# epoch= 2  step= 279  accuracy= 0.16
# epoch= 2  step= 280  accuracy= 0.11
# epoch= 2  step= 281  accuracy= 0.13
# epoch= 2  step= 282  accuracy= 0.09
# epoch= 2  step= 283  accuracy= 0.1
# epoch= 2  step= 284  accuracy= 0.15
# epoch= 2  step= 285  accuracy= 0.06
# epoch= 2  step= 286  accuracy= 0.13
# epoch= 2  step= 287  accuracy= 0.12
# epoch= 2  step= 288  accuracy= 0.15
# epoch= 2  step= 289  accuracy= 0.11
# epoch= 2  step= 290  accuracy= 0.11
# epoch= 2  step= 291  accuracy= 0.14
# epoch= 2  step= 292  accuracy= 0.17
# epoch= 2  step= 293  accuracy= 0.12
# epoch= 2  step= 294  accuracy= 0.12
# epoch= 2  step= 295  accuracy= 0.14
# epoch= 2  step= 296  accuracy= 0.18
# epoch= 2  step= 297  accuracy= 0.11
# epoch= 2  step= 298  accuracy= 0.08
# epoch= 2  step= 299  accuracy= 0.13
# epoch= 2  step= 300  accuracy= 0.13
# epoch= 2  step= 301  accuracy= 0.11
# epoch= 2  step= 302  accuracy= 0.13
# epoch= 2  step= 303  accuracy= 0.11
# epoch= 2  step= 304  accuracy= 0.2
# epoch= 2  step= 305  accuracy= 0.18
# epoch= 2  step= 306  accuracy= 0.1
# epoch= 2  step= 307  accuracy= 0.1
# epoch= 2  step= 308  accuracy= 0.1
# epoch= 2  step= 309  accuracy= 0.12
# epoch= 2  step= 310  accuracy= 0.11
# epoch= 2  step= 311  accuracy= 0.11
# epoch= 2  step= 312  accuracy= 0.19
# epoch= 2  step= 313  accuracy= 0.16
# epoch= 2  step= 314  accuracy= 0.11
# epoch= 2  step= 315  accuracy= 0.17
# epoch= 2  step= 316  accuracy= 0.11
# epoch= 2  step= 317  accuracy= 0.15
# epoch= 2  step= 318  accuracy= 0.14
# epoch= 2  step= 319  accuracy= 0.11
# epoch= 2  step= 320  accuracy= 0.14
# epoch= 2  step= 321  accuracy= 0.12
# epoch= 2  step= 322  accuracy= 0.13
# epoch= 2  step= 323  accuracy= 0.1
# epoch= 2  step= 324  accuracy= 0.13
# epoch= 2  step= 325  accuracy= 0.12
# epoch= 2  step= 326  accuracy= 0.1
# epoch= 2  step= 327  accuracy= 0.14
# epoch= 2  step= 328  accuracy= 0.13
# epoch= 2  step= 329  accuracy= 0.14
# epoch= 2  step= 330  accuracy= 0.11
# epoch= 2  step= 331  accuracy= 0.06
# epoch= 2  step= 332  accuracy= 0.09
# epoch= 2  step= 333  accuracy= 0.11
# epoch= 2  step= 334  accuracy= 0.17
# epoch= 2  step= 335  accuracy= 0.11
# epoch= 2  step= 336  accuracy= 0.1
# epoch= 2  step= 337  accuracy= 0.13
# epoch= 2  step= 338  accuracy= 0.16
# epoch= 2  step= 339  accuracy= 0.08
# epoch= 2  step= 340  accuracy= 0.17
# epoch= 2  step= 341  accuracy= 0.08
# epoch= 2  step= 342  accuracy= 0.1
# epoch= 2  step= 343  accuracy= 0.15
# epoch= 2  step= 344  accuracy= 0.09
# epoch= 2  step= 345  accuracy= 0.15
# epoch= 2  step= 346  accuracy= 0.12
# epoch= 2  step= 347  accuracy= 0.15
# epoch= 2  step= 348  accuracy= 0.1
# epoch= 2  step= 349  accuracy= 0.15
# epoch= 2  step= 350  accuracy= 0.12
# epoch= 2  step= 351  accuracy= 0.11
# epoch= 2  step= 352  accuracy= 0.15
# epoch= 2  step= 353  accuracy= 0.2
# epoch= 2  step= 354  accuracy= 0.12
# epoch= 2  step= 355  accuracy= 0.13
# epoch= 2  step= 356  accuracy= 0.08
# epoch= 2  step= 357  accuracy= 0.16
# epoch= 2  step= 358  accuracy= 0.06
# epoch= 2  step= 359  accuracy= 0.21
# epoch= 2  step= 360  accuracy= 0.17
# epoch= 2  step= 361  accuracy= 0.15
# epoch= 2  step= 362  accuracy= 0.14
# epoch= 2  step= 363  accuracy= 0.12
# epoch= 2  step= 364  accuracy= 0.12
# epoch= 2  step= 365  accuracy= 0.07
# epoch= 2  step= 366  accuracy= 0.15
# epoch= 2  step= 367  accuracy= 0.14
# epoch= 2  step= 368  accuracy= 0.15
# epoch= 2  step= 369  accuracy= 0.13
# epoch= 2  step= 370  accuracy= 0.1
# epoch= 2  step= 371  accuracy= 0.14
# epoch= 2  step= 372  accuracy= 0.09
# epoch= 2  step= 373  accuracy= 0.1
# epoch= 2  step= 374  accuracy= 0.18
# epoch= 2  step= 375  accuracy= 0.07
# epoch= 2  step= 376  accuracy= 0.14
# epoch= 2  step= 377  accuracy= 0.13
# epoch= 2  step= 378  accuracy= 0.15
# epoch= 2  step= 379  accuracy= 0.07
# epoch= 2  step= 380  accuracy= 0.14
# epoch= 2  step= 381  accuracy= 0.09
# epoch= 2  step= 382  accuracy= 0.12
# epoch= 2  step= 383  accuracy= 0.1
# epoch= 2  step= 384  accuracy= 0.14
# epoch= 2  step= 385  accuracy= 0.16
# epoch= 2  step= 386  accuracy= 0.13
# epoch= 2  step= 387  accuracy= 0.15
# epoch= 2  step= 388  accuracy= 0.12
# epoch= 2  step= 389  accuracy= 0.15
# epoch= 2  step= 390  accuracy= 0.17
# epoch= 2  step= 391  accuracy= 0.13
# epoch= 2  step= 392  accuracy= 0.11
# epoch= 2  step= 393  accuracy= 0.13
# epoch= 2  step= 394  accuracy= 0.11
# epoch= 2  step= 395  accuracy= 0.08
# epoch= 2  step= 396  accuracy= 0.07
# epoch= 2  step= 397  accuracy= 0.14
# epoch= 2  step= 398  accuracy= 0.15
# epoch= 2  step= 399  accuracy= 0.15
# epoch= 2  step= 400  accuracy= 0.17
# epoch= 2  step= 401  accuracy= 0.11
# epoch= 2  step= 402  accuracy= 0.13
# epoch= 2  step= 403  accuracy= 0.18
# epoch= 2  step= 404  accuracy= 0.1
# epoch= 2  step= 405  accuracy= 0.13
# epoch= 2  step= 406  accuracy= 0.13
# epoch= 2  step= 407  accuracy= 0.13
# epoch= 2  step= 408  accuracy= 0.06
# epoch= 2  step= 409  accuracy= 0.08
# epoch= 2  step= 410  accuracy= 0.09
# epoch= 2  step= 411  accuracy= 0.19
# epoch= 2  step= 412  accuracy= 0.12
# epoch= 2  step= 413  accuracy= 0.11
# epoch= 2  step= 414  accuracy= 0.13
# epoch= 2  step= 415  accuracy= 0.16
# epoch= 2  step= 416  accuracy= 0.11
# epoch= 2  step= 417  accuracy= 0.12
# epoch= 2  step= 418  accuracy= 0.12
# epoch= 2  step= 419  accuracy= 0.11
# epoch= 2  step= 420  accuracy= 0.12
# epoch= 2  step= 421  accuracy= 0.11
# epoch= 2  step= 422  accuracy= 0.12
# epoch= 2  step= 423  accuracy= 0.13
# epoch= 2  step= 424  accuracy= 0.17
# epoch= 2  step= 425  accuracy= 0.11
# epoch= 2  step= 426  accuracy= 0.14
# epoch= 2  step= 427  accuracy= 0.13
# epoch= 2  step= 428  accuracy= 0.14
# epoch= 2  step= 429  accuracy= 0.13
# epoch= 2  step= 430  accuracy= 0.2
# epoch= 2  step= 431  accuracy= 0.12
# epoch= 2  step= 432  accuracy= 0.12
# epoch= 2  step= 433  accuracy= 0.17
# epoch= 2  step= 434  accuracy= 0.1
# epoch= 2  step= 435  accuracy= 0.17
# epoch= 2  step= 436  accuracy= 0.1
# epoch= 2  step= 437  accuracy= 0.15
# epoch= 2  step= 438  accuracy= 0.1
# epoch= 2  step= 439  accuracy= 0.18
# epoch= 2  step= 440  accuracy= 0.11
# epoch= 2  step= 441  accuracy= 0.15
# epoch= 2  step= 442  accuracy= 0.14
# epoch= 2  step= 443  accuracy= 0.09
# epoch= 2  step= 444  accuracy= 0.14
# epoch= 2  step= 445  accuracy= 0.12
# epoch= 2  step= 446  accuracy= 0.14
# epoch= 2  step= 447  accuracy= 0.07
# epoch= 2  step= 448  accuracy= 0.11
# epoch= 2  step= 449  accuracy= 0.15
# epoch= 2  step= 450  accuracy= 0.16
# epoch= 2  step= 451  accuracy= 0.15
# epoch= 2  step= 452  accuracy= 0.11
# epoch= 2  step= 453  accuracy= 0.08
# epoch= 2  step= 454  accuracy= 0.09
# epoch= 2  step= 455  accuracy= 0.07
# epoch= 2  step= 456  accuracy= 0.08
# epoch= 2  step= 457  accuracy= 0.12
# epoch= 2  step= 458  accuracy= 0.16
# epoch= 2  step= 459  accuracy= 0.16
# epoch= 2  step= 460  accuracy= 0.14
# epoch= 2  step= 461  accuracy= 0.14
# epoch= 2  step= 462  accuracy= 0.15
# epoch= 2  step= 463  accuracy= 0.17
# epoch= 2  step= 464  accuracy= 0.1
# epoch= 2  step= 465  accuracy= 0.13
# epoch= 2  step= 466  accuracy= 0.15
# epoch= 2  step= 467  accuracy= 0.11
# epoch= 2  step= 468  accuracy= 0.15
# epoch= 2  step= 469  accuracy= 0.13
# epoch= 2  step= 470  accuracy= 0.15
# epoch= 2  step= 471  accuracy= 0.19
# epoch= 2  step= 472  accuracy= 0.15
# epoch= 2  step= 473  accuracy= 0.13
# epoch= 2  step= 474  accuracy= 0.1
# epoch= 2  step= 475  accuracy= 0.13
# epoch= 2  step= 476  accuracy= 0.13
# epoch= 2  step= 477  accuracy= 0.08
# epoch= 2  step= 478  accuracy= 0.13
# epoch= 2  step= 479  accuracy= 0.15
# epoch= 2  step= 480  accuracy= 0.17
# epoch= 2  step= 481  accuracy= 0.14
# epoch= 2  step= 482  accuracy= 0.12
# epoch= 2  step= 483  accuracy= 0.18
# epoch= 2  step= 484  accuracy= 0.14
# epoch= 2  step= 485  accuracy= 0.16
# epoch= 2  step= 486  accuracy= 0.14
# epoch= 2  step= 487  accuracy= 0.19
# epoch= 2  step= 488  accuracy= 0.07
# epoch= 2  step= 489  accuracy= 0.11
# epoch= 2  step= 490  accuracy= 0.08
# epoch= 2  step= 491  accuracy= 0.12
# epoch= 2  step= 492  accuracy= 0.14
# epoch= 2  step= 493  accuracy= 0.12
# epoch= 2  step= 494  accuracy= 0.1
# epoch= 2  step= 495  accuracy= 0.15
# epoch= 2  step= 496  accuracy= 0.08
# epoch= 2  step= 497  accuracy= 0.08
# epoch= 2  step= 498  accuracy= 0.1
# epoch= 2  step= 499  accuracy= 0.08
# epoch= 2  step= 500  accuracy= 0.13
# epoch= 2  step= 501  accuracy= 0.14
# epoch= 2  step= 502  accuracy= 0.14
# epoch= 2  step= 503  accuracy= 0.13
# epoch= 2  step= 504  accuracy= 0.16
# epoch= 2  step= 505  accuracy= 0.16
# epoch= 2  step= 506  accuracy= 0.11
# epoch= 2  step= 507  accuracy= 0.22
# epoch= 2  step= 508  accuracy= 0.11
# epoch= 2  step= 509  accuracy= 0.13
# epoch= 2  step= 510  accuracy= 0.17
# epoch= 2  step= 511  accuracy= 0.13
# epoch= 2  step= 512  accuracy= 0.07
# epoch= 2  step= 513  accuracy= 0.1
# epoch= 2  step= 514  accuracy= 0.1
# epoch= 2  step= 515  accuracy= 0.1
# epoch= 2  step= 516  accuracy= 0.09
# epoch= 2  step= 517  accuracy= 0.16
# epoch= 2  step= 518  accuracy= 0.19
# epoch= 2  step= 519  accuracy= 0.14
# epoch= 2  step= 520  accuracy= 0.14
# epoch= 2  step= 521  accuracy= 0.07
# epoch= 2  step= 522  accuracy= 0.14
# epoch= 2  step= 523  accuracy= 0.16
# epoch= 2  step= 524  accuracy= 0.11
# epoch= 2  step= 525  accuracy= 0.1
# epoch= 2  step= 526  accuracy= 0.15
# epoch= 2  step= 527  accuracy= 0.13
# epoch= 2  step= 528  accuracy= 0.16
# epoch= 2  step= 529  accuracy= 0.1
# epoch= 2  step= 530  accuracy= 0.17
# epoch= 2  step= 531  accuracy= 0.21
# epoch= 2  step= 532  accuracy= 0.15
# epoch= 2  step= 533  accuracy= 0.1
# epoch= 2  step= 534  accuracy= 0.14
# epoch= 2  step= 535  accuracy= 0.11
# epoch= 2  step= 536  accuracy= 0.12
# epoch= 2  step= 537  accuracy= 0.12
# epoch= 2  step= 538  accuracy= 0.15
# epoch= 2  step= 539  accuracy= 0.12
# epoch= 2  step= 540  accuracy= 0.18
# epoch= 2  step= 541  accuracy= 0.12
# epoch= 2  step= 542  accuracy= 0.08
# epoch= 2  step= 543  accuracy= 0.13
# epoch= 2  step= 544  accuracy= 0.14
# epoch= 2  step= 545  accuracy= 0.14
# epoch= 2  step= 546  accuracy= 0.14
# epoch= 2  step= 547  accuracy= 0.12
